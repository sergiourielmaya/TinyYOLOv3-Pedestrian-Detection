# %%
import sys
sys.path.append("/home/sergio/TinyYOLOv3-Pedestrian-Detection")

from YOLOblocks import TinyYOLOv3,BasicBlock,PredictionLayer#,YOLOLossBasicBlock
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
#from tensorflow.python.tools import freeze_graph
#from skimage.io import imread,imshow
#from skimage.transform import resize 
import time
#from tensorflow.compat.v1.image import decode_image
import imgaug.augmenters as iaa
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
import os

# %% [markdown]
# ## Dataset preparation

# %%
image_feature_description = {
    'bboxes': tf.io.FixedLenFeature([], tf.string),
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    'num_real_boxes':tf.io.FixedLenFeature([], tf.int64),
}

# %%
def get_iou_matrix_tf(box_arr1, box_arr2):
    
    box_arr1 = box_arr1 -tf.tile(box_arr1[:,:2],[1,2])
    #print(box_arr1)
    x11, y11, x12, y12 = tf.split(box_arr1, 4, axis=1)
    x21, y21, x22, y22 = tf.split(box_arr2, 4, axis=1)
    xA = tf.maximum(x11, tf.transpose(x21))
    yA = tf.maximum(y11, tf.transpose(y21))
    xB = tf.minimum(x12, tf.transpose(x22))
    yB = tf.minimum(y12, tf.transpose(y22))
    interArea = tf.maximum((xB - xA + 1e-9), 0) * tf.maximum((yB - yA + 1e-9), 0)
    boxAArea = (x12 - x11 + 1e-9) * (y12 - y11 + 1e-9)
    boxBArea = (x22 - x21 + 1e-9) * (y22 - y21 + 1e-9)
    iou = interArea / (boxAArea + tf.transpose(boxBArea) - interArea)
    return iou,tf.argmax(iou,axis=1)#[:,tf.newaxis]


def fill_yolo_output(boxes,grid_size,num_anchors,which_anchor_box,which_anchor_box_index):
    #print(boxes.shape)
    #noobj_mask = tf.ones((1,grid_size*grid_size*num_anchors))
    #print(noobj_mask.shape)
    
    x_min,y_min,x_max,y_max =tf.split(boxes,4,axis=1)

    #Transforma las coordenadas de (xmin,ymin,xmax,ymax) --> (xcenter,ycenter,width,height)
    width = x_max-x_min
    height = y_max-y_min
    x_global =x_min + tf.math.divide(x_max - x_min,2)
    y_global =y_min + tf.math.divide(y_max - y_min,2)
    
    
    x_min_anchor,y_min_anchor,x_max_anchor,y_max_anchor =tf.split(which_anchor_box,4,axis=1)
    
    width_anchor = x_max_anchor-x_min_anchor
    height_anchor = y_max_anchor-y_min_anchor
    x_global_anchor =x_min_anchor + tf.math.divide(x_max_anchor - x_min_anchor,2)
    y_global_anchor =y_min_anchor + tf.math.divide(y_max_anchor - y_min_anchor,2)   

    
    #print("el x original",x_global)
    #print("el y original",y_global)
    #print("el w original",width)
    #print("el h original",height)
    
    #porción de la imagen que hay en cada celda
    pixel_per_grid = tf.math.divide(1.,grid_size)
    #print(pixel_per_grid)
    
    #Obtenemos la coordenada de la celda donde están los boundingboxes
    offset_grid_x = x_global//pixel_per_grid
    offset_grid_y = y_global//pixel_per_grid
    
    #Obtenemos el el centro locacon referencia  al celda encontrada previamente
    x_local =tf.math.floormod(x_global,pixel_per_grid)
    y_local =tf.math.floormod(y_global,pixel_per_grid)
    #print(x_local,y_local)
    
    #Valores tx e ty del groudtruth
    tx = tf.math.log(x_local + 1e-07/(1-x_local))
    ty = tf.math.log(y_local+1e-07/(1-y_local))
    tw = tf.math.log(tf.math.divide(width+1e-07,width_anchor))
    th = tf.math.log(tf.math.divide(height+1e-07,height_anchor))
    tobj_mask = tf.ones_like(tx)
    tobj = tf.concat([tobj_mask,tobj_mask],axis=0)
    
    #tnoobj = tf.zeros_like(tx)    
    #tobj = tf.ones((grid_size*grid_size*num_anchors,1))
    #tnoobj = tf.zeros((grid_size*grid_size*num_anchors,1))
    #print("Lo que la red debe predecir",tx.numpy(),ty.numpy(),tw.numpy(),th.numpy())
    #x_global = (offset_grid_x * pixel_per_grid) + tf.math.sigmoid(tx)
    #y_global = (offset_grid_y * pixel_per_grid) + tf.math.sigmoid(ty)
    #w = width_anchor*tf.math.exp(tw)
    #h = height_anchor*tf.math.exp(th)
    #print("obtnemos el x_real",x_global)
    #print("obtenemos el y_real",y_global)
    #print("obtenemos el w real",w)
    #print("obtenemos el h real",h)
    
    
    #print(which_anchor_box_index)
    residuo = tf.math.floormod(which_anchor_box_index,2)[:,tf.newaxis]
    coord = tf.cast(2*(offset_grid_y*grid_size + offset_grid_x),dtype=tf.int64)
    
    coord_objectness = tf.cast(2*(offset_grid_y*grid_size + offset_grid_x),dtype=tf.int64)
    coord_objectness2 = coord_objectness+1
    coord_objectess_global = tf.concat([coord_objectness,coord_objectness2],axis=0)
    
    output_position = residuo+coord
    print("tipo de aoutput_positivon",output_position)
    
    print(output_position)
    
    dense_shape = grid_size*grid_size*num_anchors
    tx_vector = tf.sparse.reorder(tf.sparse.SparseTensor(indices=output_position, values=tx[:,0], dense_shape=[dense_shape]))
    ty_vector = tf.sparse.reorder(tf.sparse.SparseTensor(indices=output_position, values=ty[:,0], dense_shape=[dense_shape]))
    tw_vector = tf.sparse.reorder(tf.sparse.SparseTensor(indices=output_position, values=tw[:,0], dense_shape=[dense_shape]))
    th_vector = tf.sparse.reorder(tf.sparse.SparseTensor(indices=output_position, values=th[:,0], dense_shape=[dense_shape]))
    obj_mask = tf.sparse.reorder(tf.sparse.SparseTensor(indices=output_position, values=tobj_mask[:,0], dense_shape=[dense_shape]))
    objectness_vector = tf.sparse.reorder(tf.sparse.SparseTensor(indices=coord_objectess_global, values=tobj[:,0], dense_shape=[dense_shape]))
    #noobj_mask = tf.sparse.reorder(tf.sparse.SparseTensor(indices=output_position, values=tnoobj[:,0], dense_shape=[dense_shape]))
    #obj_mask =tx_vector=ty_vector=tw_vector=th_vector = tf.zeros((1,grid_size*grid_size*num_anchors))
    
    tx_vector_dense = tf.sparse.to_dense(tx_vector, default_value=0, validate_indices=False, name="Dense_tx")
    ty_vector_dense = tf.sparse.to_dense(ty_vector, default_value=0, validate_indices=False, name="Dense_ty")
    tw_vector_dense = tf.sparse.to_dense(tw_vector, default_value=0, validate_indices=False, name="Dense_tw")
    th_vector_dense = tf.sparse.to_dense(th_vector, default_value=0, validate_indices=False, name="Dense_th")
    obj_mask_dense =  tf.sparse.to_dense(obj_mask, default_value=0, validate_indices=False, name="Dense_obj")
    #noobj_mask_dense = 1-obj_mask_dense
    objectness_vector_dense =  tf.sparse.to_dense(objectness_vector, default_value=0, validate_indices=False)
    
    #noobj_mask_dense= tf.sparse.to_dense(noobj_mask, default_value=1, validate_indices=False, name="Dense_noobj")
    ##print(tx_vector.to_dense)
    #print(tf.sparse.to_dense(tx_vector, default_value=0, validate_indices=True, name=None)
    #tx_vector=tx_vector[[3,2],]
    #tx_vector[output_position[:,0]] = tx
    #print("coordenada de la salida:",output_position)
    
    #return ((tx_vector_dense,ty_vector_dense,obj_mask_dense),(tw_vector_dense,th_vector_dense,obj_mask_dense),(objectness),(objectness))
    
    return tx_vector_dense,ty_vector_dense,tw_vector_dense,th_vector_dense,obj_mask_dense,objectness_vector_dense

def build_targets(image,image_bboxes,num_real_boxes,anchor_boxes):
    
    images_bboxes_original = image_bboxes
    #Obtenemos los boduing boxes que son reales
    image_bboxes = image_bboxes[:num_real_boxes,:]
    #print("Bouding boxes de la imagen",image_bboxes)
    #Obteneos  la matriz de IoU , y el índice del anchor box que dió mejor resultado
    
    image_bboxes = tf.math.divide(image_bboxes,416)
    iou_matrix,which_anchor_box_index = get_iou_matrix_tf(image_bboxes,anchor_boxes)
    
    print(which_anchor_box_index)

    #Indices de los bouding boxes que irian en cada salida, index_best_ yolo nos dice que bouding boxes de la imagen van a la salida YOLO1,
    #porque su mejor IoU fue con los dos anchor boxes mas grandes
    index_best_yolo1 = tf.where(which_anchor_box_index>=2)[:,0]
    index_best_yolo2 = tf.where(which_anchor_box_index<2)[:,0]
    index_best_anchor_yolo1 = tf.gather(which_anchor_box_index,index_best_yolo1,axis=0)
    index_best_anchor_yolo2 = tf.gather(which_anchor_box_index,index_best_yolo2,axis=0)
    
    print(index_best_yolo1)
    print(index_best_anchor_yolo1)

    print(index_best_yolo2)
    print(index_best_anchor_yolo2)

    
    best_bboxes_yolo1 = tf.gather(image_bboxes,index_best_yolo1,axis =0)
    best_anchors_yolo1 = tf.gather(anchor_boxes,index_best_anchor_yolo1, axis =0) #LOs dos anchor boxes grandes corrsponden a YOLO
    best_bboxes_yolo2 = tf.gather(image_bboxes,index_best_yolo2,axis =0)
    best_anchors_yolo2 = tf.gather(anchor_boxes,index_best_anchor_yolo2, axis =0) #Los dos anchor boxes pequeños corresponden a YOLO2
    
    
    if best_anchors_yolo1.shape[0] !=0:
        tx_vector_yolo1,ty_vector_yolo1,tw_vector_yolo1,th_vector_yolo1,obj_mask_yolo1,obj_vector_yolo1= fill_yolo_output(best_bboxes_yolo1,13,2,best_anchors_yolo1,index_best_anchor_yolo1)
    else:
        tx_vector_yolo1=ty_vector_yolo1=tw_vector_yolo1=th_vector_yolo1=obj_mask_yolo1= obj_vector_yolo1=tf.zeros((1,grid_size*grid_size*num_anchors))
        #noobj_mask_yolo1 = tf.ones((1,13*13*num_anchors))
    
    if best_anchors_yolo2.shape[0] != 0:
        tx_vector_yolo2,ty_vector_yolo2,tw_vector_yolo2,th_vector_yolo2,obj_mask_yolo2,obj_vector_yolo2 = fill_yolo_output(best_bboxes_yolo2,26,2,best_anchors_yolo2,index_best_anchor_yolo2)
    else:
        tx_vector_yolo2=ty_vector_yolo2=tw_vector_yolo2=th_vector_yolo2=obj_mask_yolo2 = obj_vector_yolo2=tf.zeros((1,grid_size*grid_size*num_anchors))
        #noobj_mask_yolo2 = tf.ones((1,26*26*num_anchors))
        
    tx_vector = tf.concat([tx_vector_yolo1,tx_vector_yolo2],axis=0)[:,tf.newaxis]
    ty_vector = tf.concat([ty_vector_yolo1,ty_vector_yolo2],axis=0)[:,tf.newaxis]
    tw_vector = tf.concat([tw_vector_yolo1,tw_vector_yolo2],axis=0)[:,tf.newaxis]
    th_vector = tf.concat([th_vector_yolo1,th_vector_yolo2],axis=0)[:,tf.newaxis]
    obj_mask = tf.concat([obj_mask_yolo1,obj_mask_yolo2],axis=0)[:,tf.newaxis]
    #noobj_mask = tf.concat([noobj_mask_yolo1,noobj_mask_yolo2],axis=0)[:,tf.newaxis]
    obj_vector = tf.concat([obj_vector_yolo1,obj_vector_yolo2],axis=0)[:,tf.newaxis]
    
    #output = tf.concat([tx_vector,ty_vector,tw_vector,th_vector,obj_mask,noobj_mask,obj_vector],axis=1)
    #images_bboxes_original
    #return image,output
    #Vamos a regresar obj mask que es 1 cuando hay objeto en grid y el anchor box especifico
    return tf.cast(image,tf.float32)/255,(tf.concat([tx_vector,ty_vector,obj_mask],axis=1),tf.concat([tw_vector,th_vector,obj_mask],axis=1),(obj_mask),(obj_mask))

def imgaug_data_augmentation(image,bboxes,num_real_boxes):
    im_shape = image.shape
    bbs = BoundingBoxesOnImage.from_xyxy_array(bboxes*416, shape=(416,416))
    
    policy = np.random.randint(5)
    
    #policy = 2
    if policy == 0:
        
        p = np.random.random()
        if p<=0.6:
            aug = iaa.TranslateX(px=(-60, 60),cval=128)
            image, bbs = aug(image=image, bounding_boxes=bbs)
            #bbs.remove_out_of_image().clip_out_of_image()
    
        p = np.random.random()
        if p<=0.8:
            aug = iaa.HistogramEqualization()
            image, bbs = aug(image=image, bounding_boxes=bbs)
            #bbs.remove_out_of_image().clip_out_of_image()
    
    elif policy==1:
        
        p=np.random.random()
        if p<=0.2:
            aug = iaa.TranslateY(px=(int(-0.18*416), int(0.18*416)),cval=128)
            for i in bbs.to_xyxy_array(np.int32)[:num_real_boxes,:]:
                bbox = image[i[1]:i[3],i[0]:i[2]]
                bbox_augmented = aug(image=bbox)
                image[i[1]:i[3],i[0]:i[2]] = bbox_augmented
        
        p=np.random.random()
        if p<=0.8:
            square_size = np.random.randint(48)
            aug = iaa.Cutout(nb_iterations=1, size=square_size/416, squared=True)
            image, bbs = aug(image=image, bounding_boxes=bbs)
            #bbs.remove_out_of_image().clip_out_of_image()
            
    elif policy==2:
        p=np.random.random()
        if p<=1:
            aug = iaa.ShearY(shear=(int(-0.06*416), int(0.06*416)), order=1, cval=128)
            image, bbs = aug(image=image, bounding_boxes=bbs)
            #bbs.remove_out_of_image().clip_out_of_image()
            
        p=np.random.random()
        if p<=0.6:
            aug = iaa.TranslateY(px=(int(-0.18*416), int(0.18*416)),cval=128)
            for i in bbs.to_xyxy_array(np.int32)[:num_real_boxes,:]:
                bbox = image[i[1]:i[3],i[0]:i[2]]
                bbox_augmented = aug(image=bbox)
                image[i[1]:i[3],i[0]:i[2]] = bbox_augmented
            
    elif policy==3:
        p=np.random.random()
        if p<=0.6:    
            aug = iaa.Rotate(rotate=(-30, 30), order=1, cval=128)
            image, bbs = aug(image=image, bounding_boxes=bbs)
            #bbs_aug.remove_out_of_image().clip_out_of_image()
        
        p=np.random.random()
        if p<=1:
            aug = iaa.MultiplySaturation((0.54, 1.54))
            image, bbs = aug(image=image, bounding_boxes=bbs)
            #bbs.remove_out_of_image().clip_out_of_image()
            
    bbs.remove_out_of_image()
    
    return image,np.clip(bbs.to_xyxy_array(np.float32),1,415),num_real_boxes
    
    
def preprocessing(example_proto):
    image_features = tf.io.parse_single_example(example_proto, image_feature_description)
    image = tf.image.decode_jpeg(image_features['image_raw'],channels = 3)
    image = tf.cast(tf.image.resize(image,size=(416,416)), tf.uint8)
    bboxes =  tf.io.parse_tensor(image_features['bboxes'], out_type=tf.float32)
    
    num_real_boxes = image_features['num_real_boxes']
    return image,bboxes,num_real_boxes

def preprocessing_validation_set(example_proto):
    image_features = tf.io.parse_single_example(example_proto, image_feature_description)
    image = tf.image.decode_jpeg(image_features['image_raw'],channels = 3)
    image = tf.cast(tf.image.resize(image,size=(416,416)), tf.uint8)
    bboxes =  tf.io.parse_tensor(image_features['bboxes'], out_type=tf.float32)
    bboxes = tf.clip_by_value(bboxes*416,1,415)
    
    num_real_boxes = image_features['num_real_boxes']
    return image,bboxes,tf.cast(num_real_boxes,tf.int64)
    
@tf.function(input_signature=[tf.TensorSpec((416,416,3), tf.uint8),tf.TensorSpec((None,4), tf.float32),tf.TensorSpec((), tf.int64)]) 
def tf_numpy_albumentations_real(image,bboxes,num_real_boxes):
    
    boxes_shape = bboxes.shape
    im_shape = image.shape

    image,bboxes,num_real_boxes = tf.numpy_function(imgaug_data_augmentation,[image,bboxes,num_real_boxes],Tout =[tf.uint8,tf.float32,tf.int64])
 
    image.set_shape(im_shape)
    bboxes.set_shape(boxes_shape)
    print("Imagen data type",image.dtype)
    print("Bboxes data type",bboxes.dtype)
    print("num_real_boxes",num_real_boxes.dtype)

    return image,bboxes,num_real_boxes

# %%
#USANDO TF.IMAGE MODULE
#anchors =tf.constant(np.array([[0,0,0.015,0.037],[0,0,0.043,0.104],[0,0,0.11,0.278],[0,0,0.351,0.66]]),dtype=tf.float32)
anchors =tf.constant(np.array([[0,0,0.026,0.062],[0,0,0.067,0.183],[0,0,0.128,0.323],[0,0,0.343,0.650]]),dtype=tf.float32)

os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")
filenames = os. listdir()
raw_image_dataset = tf.data.TFRecordDataset(filenames)

os.chdir("/home/sergio/Documents/pedestrian_dataset_val_tfr")
filenames = os. listdir()
raw_image_dataset_val =tf.data.TFRecordDataset(filenames)

os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")
#.shuffle(70000)
train_dataset = raw_image_dataset.map(preprocessing,num_parallel_calls=8)
train_dataset = train_dataset.map(tf_numpy_albumentations_real,num_parallel_calls=8)
train_dataset = train_dataset.map(lambda x,y,z:build_targets(x,y,z,anchors),num_parallel_calls=8)
train_dataset = train_dataset.batch(16)

val_dataset = raw_image_dataset_val.map(preprocessing_validation_set,num_parallel_calls=8)
val_dataset = val_dataset.map(lambda x,y,z:build_targets(x,y,z,anchors),num_parallel_calls=8)
val_dataset = val_dataset.batch(16)
# Out:
# Imagen data type <dtype: 'uint8'>
# Bboxes data type <dtype: 'float32'>
# num_real_boxes <dtype: 'int64'>
# Tensor("ArgMax:0", shape=(None,), dtype=int64)
# Tensor("strided_slice_2:0", shape=(None,), dtype=int64)
# Tensor("GatherV2:0", shape=(None,), dtype=int64)
# Tensor("strided_slice_3:0", shape=(None,), dtype=int64)
# Tensor("GatherV2_1:0", shape=(None,), dtype=int64)
# tipo de aoutput_positivon Tensor("add_18:0", shape=(None, 1), dtype=int64)
# Tensor("add_18:0", shape=(None, 1), dtype=int64)
# tipo de aoutput_positivon Tensor("add_30:0", shape=(None, 1), dtype=int64)
# Tensor("add_30:0", shape=(None, 1), dtype=int64)
# Tensor("ArgMax:0", dtype=int64)
# Tensor("strided_slice_2:0", shape=(None,), dtype=int64)
# Tensor("GatherV2:0", dtype=int64)
# Tensor("strided_slice_3:0", shape=(None,), dtype=int64)
# Tensor("GatherV2_1:0", dtype=int64)
# tipo de aoutput_positivon Tensor("add_18:0", dtype=int64)
# Tensor("add_18:0", dtype=int64)
# tipo de aoutput_positivon Tensor("add_30:0", dtype=int64)
# Tensor("add_30:0", dtype=int64)

# %% [markdown]
# ### Loss Function

# %%
from tensorflow.keras.losses import Loss,BinaryCrossentropy,MeanSquaredError,MeanSquaredLogarithmicError
'''
def loss_xy(y_true,y_pred):
    
    mse = MeanSquaredError(reduction=tf.keras.losses.Reduction.NONE)
    
    tx_true,ty_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    tx_pred,ty_pred = tf.split(y_pred, [1,1], axis=-1)
    
    loss_x = tf.reduce_mean(tf.reduce_sum(obj_mask*(mse(tx_true,tx_pred)[:,:,tf.newaxis]),axis=1))
    loss_y = tf.reduce_mean(tf.reduce_sum(obj_mask*(mse(ty_true,ty_pred)[:,:,tf.newaxis]),axis=1))

    return loss_x+loss_y

def loss_wh(y_true,y_pred):
    
    mse = MeanSquaredError(reduction=tf.keras.losses.Reduction.NONE)
    
    tw_true,th_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    tw_pred,th_pred = tf.split(y_pred, [1,1], axis=-1)
    
    loss_w = tf.reduce_mean(tf.reduce_sum(obj_mask*(mse(tw_true,tw_pred)[:,:,tf.newaxis]),axis=1))
    loss_h = tf.reduce_mean(tf.reduce_sum(obj_mask*(mse(th_true,th_pred)[:,:,tf.newaxis]),axis=1))


    return loss_w+loss_h


def loss_xy(y_true,y_pred):
    
    msle = MeanSquaredLogarithmicError(reduction=tf.keras.losses.Reduction.NONE)

    tx_true,ty_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    tx_pred,ty_pred = tf.split(y_pred, [1,1], axis=-1)
    
    #print(tf.math.square(tx_true-tx_pred))  
    
    loss_x = tf.reduce_mean(tf.reduce_sum(obj_mask*(msle(tx_true,tx_pred)[:,:,tf.newaxis]),axis=1))
    loss_y = tf.reduce_mean(tf.reduce_sum(obj_mask*(msle(ty_true,ty_pred)[:,:,tf.newaxis]),axis=1))

    return loss_x+loss_y

def loss_wh(y_true,y_pred):

    msle = MeanSquaredLogarithmicError(reduction=tf.keras.losses.Reduction.NONE)
    
    tw_true,th_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    tw_pred,th_pred = tf.split(y_pred, [1,1], axis=-1)
    
    #print(tf.math.square(tw_true-tw_pred))

    
    loss_w = tf.reduce_mean(tf.reduce_sum(obj_mask*(msle(tw_true,tw_pred)[:,:,tf.newaxis]),axis=1))
    loss_h = tf.reduce_mean(tf.reduce_sum(obj_mask*(msle(th_true,th_pred)[:,:,tf.newaxis]),axis=1))


    return loss_w+loss_h
'''

def loss_xy(y_true,y_pred):
    
    msle = MeanSquaredLogarithmicError(reduction=tf.keras.losses.Reduction.NONE)

    tx_true,ty_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    tx_pred,ty_pred = tf.split(y_pred, [1,1], axis=-1)
    
    #print(tf.math.square(tx_true-tx_pred))  
    
    loss_x = tf.reduce_mean(tf.reduce_sum(obj_mask*(msle(tx_true,tx_pred)[:,:,tf.newaxis]),axis=1))
    loss_y = tf.reduce_mean(tf.reduce_sum(obj_mask*(msle(ty_true,ty_pred)[:,:,tf.newaxis]),axis=1))

    return loss_x+loss_y

def loss_wh(y_true,y_pred):

    mse = MeanSquaredError(reduction=tf.keras.losses.Reduction.NONE)
    
    tw_true,th_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    tw_pred,th_pred = tf.split(y_pred, [1,1], axis=-1)
    
    #print(tf.math.square(tw_true-tw_pred))

    
    loss_w = tf.reduce_mean(tf.reduce_sum(obj_mask*(mse(tf.math.exp(tw_true),tf.math.exp(tw_pred))[:,:,tf.newaxis]),axis=1))
    loss_h = tf.reduce_mean(tf.reduce_sum(obj_mask*(mse(tf.math.exp(th_true),tf.math.exp(th_pred))[:,:,tf.newaxis]),axis=1))


    return loss_w+loss_h


def loss_objectness(y_true,y_pred):
    bce = BinaryCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
    
    #tw_true,th_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    #tw_pred,th_pred = tf.split(y_pred, [1,1], axis=-1)   
    
    loss_obj =tf.reduce_mean(tf.reduce_sum( y_true*bce(y_true,y_pred)[:,tf.newaxis],axis=1))
    
    return loss_obj

def loss_no_objectness(y_true,y_pred):
    bce = BinaryCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
    
    
    loss_noobj =tf.reduce_mean(tf.reduce_sum((1-y_true)*bce(y_true,y_pred)[:,tf.newaxis],axis=1))
    
    return loss_noobj
'''
def loss_bce_objectness(y_true,y_pred):
    #bce = BinaryCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
    #tw_true,th_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)
    #tw_pred,th_pred = tf.split(y_pred, [1,1], axis=-1)   
    
    loss_obj =tf.reduce_mean(tf.reduce_sum( y_true*tf.math.log(y_pred+1e-7)[:,tf.newaxis],axis=1))
    
    return loss_obj

def loss_bce_no_objectness(y_true,y_pred):
    #bce = BinaryCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
    loss_noobj =tf.reduce_mean(tf.reduce_sum((1-y_true)*tf.math.log(1-y_pred+1e-7)[:,tf.newaxis],axis=1))
    
    return loss_noobj
'''
# Out:
# '\ndef loss_bce_objectness(y_true,y_pred):\n    #bce = BinaryCrossentropy(reduction=tf.keras.losses.Reduction.NONE)\n    #tw_true,th_true,obj_mask = tf.split(y_true, [1,1,1], axis=-1)\n    #tw_pred,th_pred = tf.split(y_pred, [1,1], axis=-1)   \n    \n    loss_obj =tf.reduce_mean(tf.reduce_sum( y_true*tf.math.log(y_pred+1e-7)[:,tf.newaxis],axis=1))\n    \n    return loss_obj\n\ndef loss_bce_no_objectness(y_true,y_pred):\n    #bce = BinaryCrossentropy(reduction=tf.keras.losses.Reduction.NONE)\n    loss_noobj =tf.reduce_mean(tf.reduce_sum((1-y_true)*tf.math.log(1-y_pred+1e-7)[:,tf.newaxis],axis=1))\n    \n    return loss_noobj\n'

# %% [markdown]
# ## Training with Model.fit()

# %%
anchors =tf.constant(np.array([[0.026,0.062],[0.067,0.183],[0.128,0.323],[0.343,0.650]]),dtype=tf.float32)
model = TinyYOLOv3(1,anchor_boxes=anchors,train=True,mode = "finetuning")
model.build(batch_input_shape=(None,416,416,3))
print(model.load_weights_darknet("/home/sergio/TinyYOLOv3-Pedestrian-Detection/yolov3-tiny.weights"))

# %%
for l in model.layers:
    print(l.name, l.trainable)
    pass

# %%
tf.random.set_seed(0)

from tensorflow.keras.metrics import TrueNegatives,TruePositives,FalseNegatives,FalsePositives,Precision,Recall

opt = tf.keras.optimizers.Nadam(learning_rate=1e-4)

losses = {"output_1": loss_xy,
          "output_2": loss_wh,
          "output_3":loss_objectness,
          "output_4":loss_no_objectness  
}

metrics = {"output_3":[Precision(),Recall(),TrueNegatives(),TruePositives(),FalseNegatives(),FalsePositives()]}
model.compile(optimizer=opt, loss=losses,metrics=metrics,loss_weights=[1,2,4,1])
os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")

# %% [markdown]
# ## Batch 16, con pesos 1,2,4,1 with lr=0.0001 y usando msle para el (x,y) y usando mse de las exponenciales para (w,h)

# %%
history = model.fit(train_dataset, epochs=50,validation_data=val_dataset)
# Out:
# Epoch 1/50
# 4607/4607 [==============================] - 526s 114ms/step - loss: 35.5272 - output_1_loss: 0.0173 - output_2_loss: 1.1741 - output_3_loss: 0.0930 - output_4_loss: 32.7897 - output_3_precision_3: 0.0735 - output_3_recall_3: 0.0562 - output_3_true_negatives_3: 124089576.0000 - output_3_true_positives_3: 15137.0000 - output_3_false_negatives_3: 254049.0000 - output_3_false_positives_3: 190947.0000 - val_loss: 14.5746 - val_output_1_loss: 2.2807e-05 - val_output_2_loss: 0.7402 - val_output_3_loss: 0.0569 - val_output_4_loss: 12.8666 - val_output_3_precision_3: 0.7133 - val_output_3_recall_3: 0.1259 - val_output_3_true_negatives_3: 5057624.0000 - val_output_3_true_positives_3: 1483.0000 - val_output_3_false_negatives_3: 10297.0000 - val_output_3_false_positives_3: 596.0000
# Epoch 2/50
# 4607/4607 [==============================] - 519s 113ms/step - loss: 15.6409 - output_1_loss: 1.3931e-04 - output_2_loss: 1.2909 - output_3_loss: 0.0556 - output_4_loss: 12.8365 - output_3_precision_3: 0.6536 - output_3_recall_3: 0.1038 - output_3_true_negatives_3: 124265736.0000 - output_3_true_positives_3: 27937.0000 - output_3_false_negatives_3: 241216.0000 - output_3_false_positives_3: 14805.0000 - val_loss: 13.5580 - val_output_1_loss: 2.3709e-08 - val_output_2_loss: 0.6825 - val_output_3_loss: 0.0540 - val_output_4_loss: 11.9769 - val_output_3_precision_3: 0.7216 - val_output_3_recall_3: 0.1571 - val_output_3_true_negatives_3: 5057506.0000 - val_output_3_true_positives_3: 1851.0000 - val_output_3_false_negatives_3: 9929.0000 - val_output_3_false_positives_3: 714.0000
# Epoch 3/50
# 4607/4607 [==============================] - 529s 115ms/step - loss: 13.7422 - output_1_loss: 8.9026e-06 - output_2_loss: 0.7128 - output_3_loss: 0.0530 - output_4_loss: 12.1046 - output_3_precision_3: 0.6617 - output_3_recall_3: 0.1324 - output_3_true_negatives_3: 124262560.0000 - output_3_true_positives_3: 35614.0000 - output_3_false_negatives_3: 233448.0000 - output_3_false_positives_3: 18210.0000 - val_loss: 12.5754 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.5664 - val_output_3_loss: 0.0513 - val_output_4_loss: 11.2374 - val_output_3_precision_3: 0.7398 - val_output_3_recall_3: 0.1832 - val_output_3_true_negatives_3: 5057461.0000 - val_output_3_true_positives_3: 2158.0000 - val_output_3_false_negatives_3: 9622.0000 - val_output_3_false_positives_3: 759.0000
# Epoch 4/50
# 4607/4607 [==============================] - 530s 115ms/step - loss: 13.3342 - output_1_loss: 1.5409e-06 - output_2_loss: 0.6723 - output_3_loss: 0.0518 - output_4_loss: 11.7825 - output_3_precision_3: 0.6662 - output_3_recall_3: 0.1485 - output_3_true_negatives_3: 124260272.0000 - output_3_true_positives_3: 39965.0000 - output_3_false_negatives_3: 229099.0000 - output_3_false_positives_3: 20020.0000 - val_loss: 12.1777 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.5420 - val_output_3_loss: 0.0500 - val_output_4_loss: 10.8938 - val_output_3_precision_3: 0.7415 - val_output_3_recall_3: 0.2046 - val_output_3_true_negatives_3: 5057380.0000 - val_output_3_true_positives_3: 2410.0000 - val_output_3_false_negatives_3: 9370.0000 - val_output_3_false_positives_3: 840.0000
# Epoch 5/50
# 4607/4607 [==============================] - 526s 114ms/step - loss: 12.9501 - output_1_loss: 2.3989e-06 - output_2_loss: 0.6379 - output_3_loss: 0.0506 - output_4_loss: 11.4718 - output_3_precision_3: 0.6719 - output_3_recall_3: 0.1650 - output_3_true_negatives_3: 124258648.0000 - output_3_true_positives_3: 44404.0000 - output_3_false_negatives_3: 224673.0000 - output_3_false_positives_3: 21687.0000 - val_loss: 11.7216 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.5369 - val_output_3_loss: 0.0482 - val_output_4_loss: 10.4550 - val_output_3_precision_3: 0.7552 - val_output_3_recall_3: 0.2296 - val_output_3_true_negatives_3: 5057343.0000 - val_output_3_true_positives_3: 2705.0000 - val_output_3_false_negatives_3: 9075.0000 - val_output_3_false_positives_3: 877.0000
# Epoch 6/50
# 4607/4607 [==============================] - 534s 116ms/step - loss: 12.5357 - output_1_loss: 1.5919e-05 - output_2_loss: 0.5974 - output_3_loss: 0.0493 - output_4_loss: 11.1437 - output_3_precision_3: 0.6813 - output_3_recall_3: 0.1844 - output_3_true_negatives_3: 124257400.0000 - output_3_true_positives_3: 49614.0000 - output_3_false_negatives_3: 219463.0000 - output_3_false_positives_3: 23212.0000 - val_loss: 11.4935 - val_output_1_loss: 7.9252e-06 - val_output_2_loss: 0.5248 - val_output_3_loss: 0.0471 - val_output_4_loss: 10.2553 - val_output_3_precision_3: 0.7609 - val_output_3_recall_3: 0.2423 - val_output_3_true_negatives_3: 5057323.0000 - val_output_3_true_positives_3: 2854.0000 - val_output_3_false_negatives_3: 8926.0000 - val_output_3_false_positives_3: 897.0000
# Epoch 7/50
# 4607/4607 [==============================] - 550s 119ms/step - loss: 12.1060 - output_1_loss: 1.8997e-06 - output_2_loss: 0.5629 - output_3_loss: 0.0479 - output_4_loss: 10.7886 - output_3_precision_3: 0.6849 - output_3_recall_3: 0.2046 - output_3_true_negatives_3: 124255136.0000 - output_3_true_positives_3: 55047.0000 - output_3_false_negatives_3: 214061.0000 - output_3_false_positives_3: 25331.0000 - val_loss: 10.8176 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.4899 - val_output_3_loss: 0.0450 - val_output_4_loss: 9.6576 - val_output_3_precision_3: 0.7861 - val_output_3_recall_3: 0.2633 - val_output_3_true_negatives_3: 5057376.0000 - val_output_3_true_positives_3: 3102.0000 - val_output_3_false_negatives_3: 8678.0000 - val_output_3_false_positives_3: 844.0000
# Epoch 8/50
# 4607/4607 [==============================] - 540s 117ms/step - loss: 11.7399 - output_1_loss: 3.8491e-07 - output_2_loss: 0.5496 - output_3_loss: 0.0466 - output_4_loss: 10.4545 - output_3_precision_3: 0.6933 - output_3_recall_3: 0.2248 - output_3_true_negatives_3: 124253696.0000 - output_3_true_positives_3: 60510.0000 - output_3_false_negatives_3: 208646.0000 - output_3_false_positives_3: 26764.0000 - val_loss: 10.3398 - val_output_1_loss: 3.0662e-10 - val_output_2_loss: 0.4551 - val_output_3_loss: 0.0435 - val_output_4_loss: 9.2556 - val_output_3_precision_3: 0.7861 - val_output_3_recall_3: 0.2988 - val_output_3_true_negatives_3: 5057262.0000 - val_output_3_true_positives_3: 3520.0000 - val_output_3_false_negatives_3: 8260.0000 - val_output_3_false_positives_3: 958.0000
# Epoch 9/50
# 4607/4607 [==============================] - 541s 117ms/step - loss: 11.4478 - output_1_loss: 2.9279e-06 - output_2_loss: 0.5320 - output_3_loss: 0.0457 - output_4_loss: 10.2011 - output_3_precision_3: 0.7027 - output_3_recall_3: 0.2431 - output_3_true_negatives_3: 124252800.0000 - output_3_true_positives_3: 65414.0000 - output_3_false_negatives_3: 203683.0000 - output_3_false_positives_3: 27677.0000 - val_loss: 9.8831 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.4524 - val_output_3_loss: 0.0416 - val_output_4_loss: 8.8118 - val_output_3_precision_3: 0.7953 - val_output_3_recall_3: 0.3338 - val_output_3_true_negatives_3: 5057208.0000 - val_output_3_true_positives_3: 3932.0000 - val_output_3_false_negatives_3: 7848.0000 - val_output_3_false_positives_3: 1012.0000
# Epoch 10/50
# 4607/4607 [==============================] - 534s 116ms/step - loss: 11.1225 - output_1_loss: 3.8094e-06 - output_2_loss: 0.5227 - output_3_loss: 0.0444 - output_4_loss: 9.8994 - output_3_precision_3: 0.7101 - output_3_recall_3: 0.2640 - output_3_true_negatives_3: 124251608.0000 - output_3_true_positives_3: 71030.0000 - output_3_false_negatives_3: 198061.0000 - output_3_false_positives_3: 28994.0000 - val_loss: 9.4303 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.4200 - val_output_3_loss: 0.0401 - val_output_4_loss: 8.4298 - val_output_3_precision_3: 0.8017 - val_output_3_recall_3: 0.3596 - val_output_3_true_negatives_3: 5057172.0000 - val_output_3_true_positives_3: 4236.0000 - val_output_3_false_negatives_3: 7544.0000 - val_output_3_false_positives_3: 1048.0000
# Epoch 11/50
# 4607/4607 [==============================] - 540s 117ms/step - loss: 10.8292 - output_1_loss: 1.3714e-06 - output_2_loss: 0.5107 - output_3_loss: 0.0434 - output_4_loss: 9.6343 - output_3_precision_3: 0.7193 - output_3_recall_3: 0.2821 - output_3_true_negatives_3: 124250856.0000 - output_3_true_positives_3: 75930.0000 - output_3_false_negatives_3: 193240.0000 - output_3_false_positives_3: 29631.0000 - val_loss: 8.9362 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.4072 - val_output_3_loss: 0.0384 - val_output_4_loss: 7.9681 - val_output_3_precision_3: 0.8161 - val_output_3_recall_3: 0.3828 - val_output_3_true_negatives_3: 5057204.0000 - val_output_3_true_positives_3: 4509.0000 - val_output_3_false_negatives_3: 7271.0000 - val_output_3_false_positives_3: 1016.0000
# Epoch 12/50
# 4607/4607 [==============================] - 546s 119ms/step - loss: 10.5211 - output_1_loss: 1.0862e-06 - output_2_loss: 0.4883 - output_3_loss: 0.0424 - output_4_loss: 9.3751 - output_3_precision_3: 0.7261 - output_3_recall_3: 0.3029 - output_3_true_negatives_3: 124249608.0000 - output_3_true_positives_3: 81516.0000 - output_3_false_negatives_3: 187587.0000 - output_3_false_positives_3: 30755.0000 - val_loss: 8.6410 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.4089 - val_output_3_loss: 0.0371 - val_output_4_loss: 7.6748 - val_output_3_precision_3: 0.8174 - val_output_3_recall_3: 0.4162 - val_output_3_true_negatives_3: 5057125.0000 - val_output_3_true_positives_3: 4903.0000 - val_output_3_false_negatives_3: 6877.0000 - val_output_3_false_positives_3: 1095.0000
# Epoch 13/50
# 4607/4607 [==============================] - 545s 118ms/step - loss: 10.2914 - output_1_loss: 5.9203e-05 - output_2_loss: 0.4884 - output_3_loss: 0.0416 - output_4_loss: 9.1482 - output_3_precision_3: 0.7373 - output_3_recall_3: 0.3215 - output_3_true_negatives_3: 124249736.0000 - output_3_true_positives_3: 86504.0000 - output_3_false_negatives_3: 182597.0000 - output_3_false_positives_3: 30822.0000 - val_loss: 8.2863 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3910 - val_output_3_loss: 0.0358 - val_output_4_loss: 7.3610 - val_output_3_precision_3: 0.8265 - val_output_3_recall_3: 0.4476 - val_output_3_true_negatives_3: 5057113.0000 - val_output_3_true_positives_3: 5273.0000 - val_output_3_false_negatives_3: 6507.0000 - val_output_3_false_positives_3: 1107.0000
# Epoch 14/50
# 4607/4607 [==============================] - 535s 116ms/step - loss: 10.0238 - output_1_loss: 2.8081e-06 - output_2_loss: 0.4744 - output_3_loss: 0.0405 - output_4_loss: 8.9129 - output_3_precision_3: 0.7419 - output_3_recall_3: 0.3387 - output_3_true_negatives_3: 124248880.0000 - output_3_true_positives_3: 91127.0000 - output_3_false_negatives_3: 177928.0000 - output_3_false_positives_3: 31704.0000 - val_loss: 8.0209 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3964 - val_output_3_loss: 0.0346 - val_output_4_loss: 7.0896 - val_output_3_precision_3: 0.8085 - val_output_3_recall_3: 0.4841 - val_output_3_true_negatives_3: 5056869.0000 - val_output_3_true_positives_3: 5703.0000 - val_output_3_false_negatives_3: 6077.0000 - val_output_3_false_positives_3: 1351.0000
# Epoch 15/50
# 4607/4607 [==============================] - 534s 116ms/step - loss: 9.8005 - output_1_loss: 3.2433e-07 - output_2_loss: 0.4742 - output_3_loss: 0.0396 - output_4_loss: 8.6935 - output_3_precision_3: 0.7517 - output_3_recall_3: 0.3573 - output_3_true_negatives_3: 124248808.0000 - output_3_true_positives_3: 96147.0000 - output_3_false_negatives_3: 172942.0000 - output_3_false_positives_3: 31758.0000 - val_loss: 7.6236 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3768 - val_output_3_loss: 0.0333 - val_output_4_loss: 6.7367 - val_output_3_precision_3: 0.8365 - val_output_3_recall_3: 0.4838 - val_output_3_true_negatives_3: 5057106.0000 - val_output_3_true_positives_3: 5699.0000 - val_output_3_false_negatives_3: 6081.0000 - val_output_3_false_positives_3: 1114.0000
# Epoch 16/50
# 4607/4607 [==============================] - 540s 117ms/step - loss: 9.6314 - output_1_loss: 7.8364e-07 - output_2_loss: 0.4758 - output_3_loss: 0.0390 - output_4_loss: 8.5237 - output_3_precision_3: 0.7584 - output_3_recall_3: 0.3709 - output_3_true_negatives_3: 124248520.0000 - output_3_true_positives_3: 99817.0000 - output_3_false_negatives_3: 169313.0000 - output_3_false_positives_3: 31792.0000 - val_loss: 7.2672 - val_output_1_loss: 3.0734e-06 - val_output_2_loss: 0.3684 - val_output_3_loss: 0.0318 - val_output_4_loss: 6.4030 - val_output_3_precision_3: 0.8379 - val_output_3_recall_3: 0.5216 - val_output_3_true_negatives_3: 5057031.0000 - val_output_3_true_positives_3: 6144.0000 - val_output_3_false_negatives_3: 5636.0000 - val_output_3_false_positives_3: 1189.0000
# Epoch 17/50
# 4607/4607 [==============================] - 544s 118ms/step - loss: 9.9032 - output_1_loss: 2.6378e-05 - output_2_loss: 0.5732 - output_3_loss: 0.0393 - output_4_loss: 8.5995 - output_3_precision_3: 0.7586 - output_3_recall_3: 0.3682 - output_3_true_negatives_3: 124248864.0000 - output_3_true_positives_3: 99064.0000 - output_3_false_negatives_3: 170004.0000 - output_3_false_positives_3: 31525.0000 - val_loss: 7.2787 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3897 - val_output_3_loss: 0.0314 - val_output_4_loss: 6.3736 - val_output_3_precision_3: 0.8431 - val_output_3_recall_3: 0.5228 - val_output_3_true_negatives_3: 5057074.0000 - val_output_3_true_positives_3: 6158.0000 - val_output_3_false_negatives_3: 5622.0000 - val_output_3_false_positives_3: 1146.0000
# Epoch 18/50
# 4607/4607 [==============================] - 538s 117ms/step - loss: 9.2431 - output_1_loss: 2.8179e-07 - output_2_loss: 0.4620 - output_3_loss: 0.0375 - output_4_loss: 8.1690 - output_3_precision_3: 0.7711 - output_3_recall_3: 0.4015 - output_3_true_negatives_3: 124248376.0000 - output_3_true_positives_3: 108094.0000 - output_3_false_negatives_3: 161118.0000 - output_3_false_positives_3: 32085.0000 - val_loss: 6.6895 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3625 - val_output_3_loss: 0.0293 - val_output_4_loss: 5.8472 - val_output_3_precision_3: 0.8456 - val_output_3_recall_3: 0.5787 - val_output_3_true_negatives_3: 5056975.0000 - val_output_3_true_positives_3: 6817.0000 - val_output_3_false_negatives_3: 4963.0000 - val_output_3_false_positives_3: 1245.0000
# Epoch 19/50
# 4607/4607 [==============================] - 534s 116ms/step - loss: 9.1434 - output_1_loss: 1.6563e-06 - output_2_loss: 0.4542 - output_3_loss: 0.0372 - output_4_loss: 8.0862 - output_3_precision_3: 0.7754 - output_3_recall_3: 0.4124 - output_3_true_negatives_3: 124248392.0000 - output_3_true_positives_3: 110991.0000 - output_3_false_negatives_3: 158138.0000 - output_3_false_positives_3: 32145.0000 - val_loss: 6.6539 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3573 - val_output_3_loss: 0.0291 - val_output_4_loss: 5.8231 - val_output_3_precision_3: 0.8492 - val_output_3_recall_3: 0.5739 - val_output_3_true_negatives_3: 5057019.0000 - val_output_3_true_positives_3: 6761.0000 - val_output_3_false_negatives_3: 5019.0000 - val_output_3_false_positives_3: 1201.0000
# Epoch 20/50
# 4607/4607 [==============================] - 535s 116ms/step - loss: 9.0123 - output_1_loss: 1.6022e-07 - output_2_loss: 0.4505 - output_3_loss: 0.0367 - output_4_loss: 7.9645 - output_3_precision_3: 0.7776 - output_3_recall_3: 0.4205 - output_3_true_negatives_3: 124248264.0000 - output_3_true_positives_3: 113155.0000 - output_3_false_negatives_3: 155960.0000 - output_3_false_positives_3: 32364.0000 - val_loss: 6.4275 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3562 - val_output_3_loss: 0.0282 - val_output_4_loss: 5.6022 - val_output_3_precision_3: 0.8695 - val_output_3_recall_3: 0.5678 - val_output_3_true_negatives_3: 5057216.0000 - val_output_3_true_positives_3: 6689.0000 - val_output_3_false_negatives_3: 5091.0000 - val_output_3_false_positives_3: 1004.0000
# Epoch 21/50
# 4607/4607 [==============================] - 447s 97ms/step - loss: 8.8467 - output_1_loss: 7.4887e-08 - output_2_loss: 0.4493 - output_3_loss: 0.0360 - output_4_loss: 7.8039 - output_3_precision_3: 0.7832 - output_3_recall_3: 0.4337 - output_3_true_negatives_3: 124248216.0000 - output_3_true_positives_3: 116723.0000 - output_3_false_negatives_3: 152384.0000 - output_3_false_positives_3: 32319.0000 - val_loss: 6.2770 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3733 - val_output_3_loss: 0.0273 - val_output_4_loss: 5.4212 - val_output_3_precision_3: 0.8609 - val_output_3_recall_3: 0.5935 - val_output_3_true_negatives_3: 5057090.0000 - val_output_3_true_positives_3: 6992.0000 - val_output_3_false_negatives_3: 4788.0000 - val_output_3_false_positives_3: 1130.0000
# Epoch 22/50
# 4607/4607 [==============================] - 436s 95ms/step - loss: 8.7243 - output_1_loss: 7.1703e-07 - output_2_loss: 0.4449 - output_3_loss: 0.0355 - output_4_loss: 7.6924 - output_3_precision_3: 0.7864 - output_3_recall_3: 0.4440 - output_3_true_negatives_3: 124247720.0000 - output_3_true_positives_3: 119518.0000 - output_3_false_negatives_3: 149637.0000 - output_3_false_positives_3: 32471.0000 - val_loss: 5.9870 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3470 - val_output_3_loss: 0.0262 - val_output_4_loss: 5.1882 - val_output_3_precision_3: 0.8646 - val_output_3_recall_3: 0.6171 - val_output_3_true_negatives_3: 5057082.0000 - val_output_3_true_positives_3: 7269.0000 - val_output_3_false_negatives_3: 4511.0000 - val_output_3_false_positives_3: 1138.0000
# Epoch 23/50
# 4607/4607 [==============================] - 432s 94ms/step - loss: 8.6138 - output_1_loss: 2.7395e-08 - output_2_loss: 0.4427 - output_3_loss: 0.0351 - output_4_loss: 7.5880 - output_3_precision_3: 0.7917 - output_3_recall_3: 0.4534 - output_3_true_negatives_3: 124248336.0000 - output_3_true_positives_3: 121985.0000 - output_3_false_negatives_3: 147045.0000 - output_3_false_positives_3: 32099.0000 - val_loss: 5.8019 - val_output_1_loss: 2.3145e-06 - val_output_2_loss: 0.3469 - val_output_3_loss: 0.0253 - val_output_4_loss: 5.0071 - val_output_3_precision_3: 0.8613 - val_output_3_recall_3: 0.6473 - val_output_3_true_negatives_3: 5056992.0000 - val_output_3_true_positives_3: 7625.0000 - val_output_3_false_negatives_3: 4155.0000 - val_output_3_false_positives_3: 1228.0000
# Epoch 24/50
# 4607/4607 [==============================] - 431s 93ms/step - loss: 8.4571 - output_1_loss: 1.7790e-05 - output_2_loss: 0.4324 - output_3_loss: 0.0345 - output_4_loss: 7.4543 - output_3_precision_3: 0.7949 - output_3_recall_3: 0.4640 - output_3_true_negatives_3: 124248384.0000 - output_3_true_positives_3: 124892.0000 - output_3_false_negatives_3: 144258.0000 - output_3_false_positives_3: 32231.0000 - val_loss: 5.7266 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3512 - val_output_3_loss: 0.0251 - val_output_4_loss: 4.9236 - val_output_3_precision_3: 0.8625 - val_output_3_recall_3: 0.6400 - val_output_3_true_negatives_3: 5057018.0000 - val_output_3_true_positives_3: 7539.0000 - val_output_3_false_negatives_3: 4241.0000 - val_output_3_false_positives_3: 1202.0000
# Epoch 25/50
# 4607/4607 [==============================] - 429s 93ms/step - loss: 8.3823 - output_1_loss: 7.7283e-08 - output_2_loss: 0.4371 - output_3_loss: 0.0341 - output_4_loss: 7.3716 - output_3_precision_3: 0.7967 - output_3_recall_3: 0.4705 - output_3_true_negatives_3: 124248176.0000 - output_3_true_positives_3: 126628.0000 - output_3_false_negatives_3: 142504.0000 - output_3_false_positives_3: 32319.0000 - val_loss: 5.6274 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3327 - val_output_3_loss: 0.0248 - val_output_4_loss: 4.8628 - val_output_3_precision_3: 0.8522 - val_output_3_recall_3: 0.6687 - val_output_3_true_negatives_3: 5056854.0000 - val_output_3_true_positives_3: 7877.0000 - val_output_3_false_negatives_3: 3903.0000 - val_output_3_false_positives_3: 1366.0000
# Epoch 26/50
# 4607/4607 [==============================] - 423s 92ms/step - loss: 8.2122 - output_1_loss: 4.4648e-06 - output_2_loss: 0.4248 - output_3_loss: 0.0334 - output_4_loss: 7.2291 - output_3_precision_3: 0.8024 - output_3_recall_3: 0.4841 - output_3_true_negatives_3: 124248200.0000 - output_3_true_positives_3: 130316.0000 - output_3_false_negatives_3: 138862.0000 - output_3_false_positives_3: 32100.0000 - val_loss: 5.3860 - val_output_1_loss: 3.3579e-06 - val_output_2_loss: 0.3313 - val_output_3_loss: 0.0237 - val_output_4_loss: 4.6286 - val_output_3_precision_3: 0.8715 - val_output_3_recall_3: 0.6690 - val_output_3_true_negatives_3: 5057058.0000 - val_output_3_true_positives_3: 7881.0000 - val_output_3_false_negatives_3: 3899.0000 - val_output_3_false_positives_3: 1162.0000
# Epoch 27/50
# 4607/4607 [==============================] - 417s 90ms/step - loss: 8.1479 - output_1_loss: 2.2891e-06 - output_2_loss: 0.4311 - output_3_loss: 0.0332 - output_4_loss: 7.1529 - output_3_precision_3: 0.8064 - output_3_recall_3: 0.4921 - output_3_true_negatives_3: 124248512.0000 - output_3_true_positives_3: 132453.0000 - output_3_false_negatives_3: 136691.0000 - output_3_false_positives_3: 31799.0000 - val_loss: 5.3425 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3297 - val_output_3_loss: 0.0234 - val_output_4_loss: 4.5897 - val_output_3_precision_3: 0.8731 - val_output_3_recall_3: 0.6749 - val_output_3_true_negatives_3: 5057064.0000 - val_output_3_true_positives_3: 7950.0000 - val_output_3_false_negatives_3: 3830.0000 - val_output_3_false_positives_3: 1156.0000
# Epoch 28/50
# 4607/4607 [==============================] - 415s 90ms/step - loss: 8.0339 - output_1_loss: 7.0506e-07 - output_2_loss: 0.4255 - output_3_loss: 0.0326 - output_4_loss: 7.0522 - output_3_precision_3: 0.8096 - output_3_recall_3: 0.5003 - output_3_true_negatives_3: 124248752.0000 - output_3_true_positives_3: 134652.0000 - output_3_false_negatives_3: 134496.0000 - output_3_false_positives_3: 31675.0000 - val_loss: 5.1775 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3257 - val_output_3_loss: 0.0226 - val_output_4_loss: 4.4355 - val_output_3_precision_3: 0.8615 - val_output_3_recall_3: 0.7035 - val_output_3_true_negatives_3: 5056888.0000 - val_output_3_true_positives_3: 8287.0000 - val_output_3_false_negatives_3: 3493.0000 - val_output_3_false_positives_3: 1332.0000
# Epoch 29/50
# 4607/4607 [==============================] - 412s 89ms/step - loss: 7.9361 - output_1_loss: 8.0082e-06 - output_2_loss: 0.4173 - output_3_loss: 0.0323 - output_4_loss: 6.9722 - output_3_precision_3: 0.8123 - output_3_recall_3: 0.5079 - output_3_true_negatives_3: 124248856.0000 - output_3_true_positives_3: 136694.0000 - output_3_false_negatives_3: 132443.0000 - output_3_false_positives_3: 31590.0000 - val_loss: 4.9428 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3208 - val_output_3_loss: 0.0216 - val_output_4_loss: 4.2146 - val_output_3_precision_3: 0.8896 - val_output_3_recall_3: 0.6939 - val_output_3_true_negatives_3: 5057206.0000 - val_output_3_true_positives_3: 8174.0000 - val_output_3_false_negatives_3: 3606.0000 - val_output_3_false_positives_3: 1014.0000
# Epoch 30/50
# 4607/4607 [==============================] - 410s 89ms/step - loss: 7.9509 - output_1_loss: 6.4167e-07 - output_2_loss: 0.4273 - output_3_loss: 0.0324 - output_4_loss: 6.9667 - output_3_precision_3: 0.8142 - output_3_recall_3: 0.5082 - output_3_true_negatives_3: 124249296.0000 - output_3_true_positives_3: 136769.0000 - output_3_false_negatives_3: 132341.0000 - output_3_false_positives_3: 31204.0000 - val_loss: 5.0354 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3220 - val_output_3_loss: 0.0219 - val_output_4_loss: 4.3039 - val_output_3_precision_3: 0.8772 - val_output_3_recall_3: 0.6987 - val_output_3_true_negatives_3: 5057068.0000 - val_output_3_true_positives_3: 8231.0000 - val_output_3_false_negatives_3: 3549.0000 - val_output_3_false_positives_3: 1152.0000
# Epoch 31/50
# 4607/4607 [==============================] - 411s 89ms/step - loss: 7.8071 - output_1_loss: 1.2087e-06 - output_2_loss: 0.4126 - output_3_loss: 0.0318 - output_4_loss: 6.8545 - output_3_precision_3: 0.8180 - output_3_recall_3: 0.5186 - output_3_true_negatives_3: 124249344.0000 - output_3_true_positives_3: 139570.0000 - output_3_false_negatives_3: 129573.0000 - output_3_false_positives_3: 31059.0000 - val_loss: 4.7626 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3151 - val_output_3_loss: 0.0207 - val_output_4_loss: 4.0495 - val_output_3_precision_3: 0.8889 - val_output_3_recall_3: 0.7135 - val_output_3_true_negatives_3: 5057170.0000 - val_output_3_true_positives_3: 8405.0000 - val_output_3_false_negatives_3: 3375.0000 - val_output_3_false_positives_3: 1050.0000
# Epoch 32/50
# 4607/4607 [==============================] - 404s 88ms/step - loss: 7.6779 - output_1_loss: 3.9421e-06 - output_2_loss: 0.4089 - output_3_loss: 0.0313 - output_4_loss: 6.7352 - output_3_precision_3: 0.8213 - output_3_recall_3: 0.5271 - output_3_true_negatives_3: 124249928.0000 - output_3_true_positives_3: 141838.0000 - output_3_false_negatives_3: 127278.0000 - output_3_false_positives_3: 30864.0000 - val_loss: 4.6403 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3146 - val_output_3_loss: 0.0201 - val_output_4_loss: 3.9308 - val_output_3_precision_3: 0.8817 - val_output_3_recall_3: 0.7368 - val_output_3_true_negatives_3: 5057055.0000 - val_output_3_true_positives_3: 8679.0000 - val_output_3_false_negatives_3: 3101.0000 - val_output_3_false_positives_3: 1165.0000
# Epoch 33/50
# 4607/4607 [==============================] - 406s 88ms/step - loss: 7.6560 - output_1_loss: 8.9232e-07 - output_2_loss: 0.4075 - output_3_loss: 0.0311 - output_4_loss: 6.7165 - output_3_precision_3: 0.8226 - output_3_recall_3: 0.5308 - output_3_true_negatives_3: 124249864.0000 - output_3_true_positives_3: 142838.0000 - output_3_false_negatives_3: 126268.0000 - output_3_false_positives_3: 30806.0000 - val_loss: 4.5587 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3125 - val_output_3_loss: 0.0196 - val_output_4_loss: 3.8552 - val_output_3_precision_3: 0.8834 - val_output_3_recall_3: 0.7395 - val_output_3_true_negatives_3: 5057070.0000 - val_output_3_true_positives_3: 8711.0000 - val_output_3_false_negatives_3: 3069.0000 - val_output_3_false_positives_3: 1150.0000
# Epoch 34/50
# 4607/4607 [==============================] - 400s 87ms/step - loss: 7.5335 - output_1_loss: 4.0202e-09 - output_2_loss: 0.4061 - output_3_loss: 0.0305 - output_4_loss: 6.5993 - output_3_precision_3: 0.8271 - output_3_recall_3: 0.5406 - output_3_true_negatives_3: 124250072.0000 - output_3_true_positives_3: 145497.0000 - output_3_false_negatives_3: 123639.0000 - output_3_false_positives_3: 30420.0000 - val_loss: 4.3248 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3013 - val_output_3_loss: 0.0186 - val_output_4_loss: 3.6480 - val_output_3_precision_3: 0.8908 - val_output_3_recall_3: 0.7517 - val_output_3_true_negatives_3: 5057134.0000 - val_output_3_true_positives_3: 8855.0000 - val_output_3_false_negatives_3: 2925.0000 - val_output_3_false_positives_3: 1086.0000
# Epoch 35/50
# 4607/4607 [==============================] - 397s 86ms/step - loss: 7.4819 - output_1_loss: 6.8222e-07 - output_2_loss: 0.4026 - output_3_loss: 0.0304 - output_4_loss: 6.5551 - output_3_precision_3: 0.8277 - output_3_recall_3: 0.5436 - output_3_true_negatives_3: 124250000.0000 - output_3_true_positives_3: 146353.0000 - output_3_false_negatives_3: 122857.0000 - output_3_false_positives_3: 30465.0000 - val_loss: 4.1937 - val_output_1_loss: 1.4107e-06 - val_output_2_loss: 0.3028 - val_output_3_loss: 0.0180 - val_output_4_loss: 3.5158 - val_output_3_precision_3: 0.9101 - val_output_3_recall_3: 0.7438 - val_output_3_true_negatives_3: 5057354.0000 - val_output_3_true_positives_3: 8762.0000 - val_output_3_false_negatives_3: 3018.0000 - val_output_3_false_positives_3: 866.0000
# Epoch 36/50
# 4607/4607 [==============================] - 395s 86ms/step - loss: 7.4497 - output_1_loss: 1.5853e-08 - output_2_loss: 0.4114 - output_3_loss: 0.0303 - output_4_loss: 6.5058 - output_3_precision_3: 0.8304 - output_3_recall_3: 0.5490 - output_3_true_negatives_3: 124250408.0000 - output_3_true_positives_3: 147757.0000 - output_3_false_negatives_3: 121361.0000 - output_3_false_positives_3: 30181.0000 - val_loss: 4.2472 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3028 - val_output_3_loss: 0.0183 - val_output_4_loss: 3.5683 - val_output_3_precision_3: 0.8735 - val_output_3_recall_3: 0.7940 - val_output_3_true_negatives_3: 5056865.0000 - val_output_3_true_positives_3: 9353.0000 - val_output_3_false_negatives_3: 2427.0000 - val_output_3_false_positives_3: 1355.0000
# Epoch 37/50
# 4607/4607 [==============================] - 403s 87ms/step - loss: 7.3700 - output_1_loss: 1.1038e-05 - output_2_loss: 0.4019 - output_3_loss: 0.0300 - output_4_loss: 6.4462 - output_3_precision_3: 0.8321 - output_3_recall_3: 0.5532 - output_3_true_negatives_3: 124250536.0000 - output_3_true_positives_3: 148886.0000 - output_3_false_negatives_3: 120237.0000 - output_3_false_positives_3: 30038.0000 - val_loss: 4.0601 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3005 - val_output_3_loss: 0.0176 - val_output_4_loss: 3.3888 - val_output_3_precision_3: 0.9073 - val_output_3_recall_3: 0.7604 - val_output_3_true_negatives_3: 5057305.0000 - val_output_3_true_positives_3: 8958.0000 - val_output_3_false_negatives_3: 2822.0000 - val_output_3_false_positives_3: 915.0000
# Epoch 38/50
# 4607/4607 [==============================] - 401s 87ms/step - loss: 7.2776 - output_1_loss: 1.2036e-06 - output_2_loss: 0.3915 - output_3_loss: 0.0296 - output_4_loss: 6.3762 - output_3_precision_3: 0.8360 - output_3_recall_3: 0.5597 - output_3_true_negatives_3: 124251032.0000 - output_3_true_positives_3: 150589.0000 - output_3_false_negatives_3: 118483.0000 - output_3_false_positives_3: 29534.0000 - val_loss: 4.0198 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.3130 - val_output_3_loss: 0.0171 - val_output_4_loss: 3.3256 - val_output_3_precision_3: 0.8927 - val_output_3_recall_3: 0.7857 - val_output_3_true_negatives_3: 5057108.0000 - val_output_3_true_positives_3: 9255.0000 - val_output_3_false_negatives_3: 2525.0000 - val_output_3_false_positives_3: 1112.0000
# Epoch 39/50
# 4607/4607 [==============================] - 394s 85ms/step - loss: 7.2553 - output_1_loss: 7.7384e-06 - output_2_loss: 0.3920 - output_3_loss: 0.0295 - output_4_loss: 6.3534 - output_3_precision_3: 0.8356 - output_3_recall_3: 0.5608 - output_3_true_negatives_3: 124250608.0000 - output_3_true_positives_3: 150930.0000 - output_3_false_negatives_3: 118207.0000 - output_3_false_positives_3: 29695.0000 - val_loss: 3.9920 - val_output_1_loss: 2.4355e-07 - val_output_2_loss: 0.3017 - val_output_3_loss: 0.0170 - val_output_4_loss: 3.3208 - val_output_3_precision_3: 0.9033 - val_output_3_recall_3: 0.7910 - val_output_3_true_negatives_3: 5057222.0000 - val_output_3_true_positives_3: 9318.0000 - val_output_3_false_negatives_3: 2462.0000 - val_output_3_false_positives_3: 998.0000
# Epoch 40/50
# 4607/4607 [==============================] - 407s 88ms/step - loss: 7.1881 - output_1_loss: 4.9618e-06 - output_2_loss: 0.3942 - output_3_loss: 0.0290 - output_4_loss: 6.2835 - output_3_precision_3: 0.8388 - output_3_recall_3: 0.5665 - output_3_true_negatives_3: 124251192.0000 - output_3_true_positives_3: 152419.0000 - output_3_false_negatives_3: 116651.0000 - output_3_false_positives_3: 29291.0000 - val_loss: 3.9658 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2977 - val_output_3_loss: 0.0168 - val_output_4_loss: 3.3032 - val_output_3_precision_3: 0.9144 - val_output_3_recall_3: 0.7743 - val_output_3_true_negatives_3: 5057366.0000 - val_output_3_true_positives_3: 9121.0000 - val_output_3_false_negatives_3: 2659.0000 - val_output_3_false_positives_3: 854.0000
# Epoch 41/50
# 4607/4607 [==============================] - 400s 87ms/step - loss: 7.1928 - output_1_loss: 9.8263e-07 - output_2_loss: 0.3971 - output_3_loss: 0.0292 - output_4_loss: 6.2820 - output_3_precision_3: 0.8388 - output_3_recall_3: 0.5681 - output_3_true_negatives_3: 124250936.0000 - output_3_true_positives_3: 152868.0000 - output_3_false_negatives_3: 116219.0000 - output_3_false_positives_3: 29387.0000 - val_loss: 3.7929 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2965 - val_output_3_loss: 0.0162 - val_output_4_loss: 3.1352 - val_output_3_precision_3: 0.9137 - val_output_3_recall_3: 0.7887 - val_output_3_true_negatives_3: 5057342.0000 - val_output_3_true_positives_3: 9291.0000 - val_output_3_false_negatives_3: 2489.0000 - val_output_3_false_positives_3: 878.0000
# Epoch 42/50
# 4607/4607 [==============================] - 392s 85ms/step - loss: 7.1084 - output_1_loss: 1.0582e-06 - output_2_loss: 0.3935 - output_3_loss: 0.0288 - output_4_loss: 6.2063 - output_3_precision_3: 0.8415 - output_3_recall_3: 0.5746 - output_3_true_negatives_3: 124251216.0000 - output_3_true_positives_3: 154698.0000 - output_3_false_negatives_3: 114536.0000 - output_3_false_positives_3: 29138.0000 - val_loss: 3.7941 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2923 - val_output_3_loss: 0.0159 - val_output_4_loss: 3.1458 - val_output_3_precision_3: 0.8994 - val_output_3_recall_3: 0.8147 - val_output_3_true_negatives_3: 5057146.0000 - val_output_3_true_positives_3: 9597.0000 - val_output_3_false_negatives_3: 2183.0000 - val_output_3_false_positives_3: 1074.0000
# Epoch 43/50
# 4607/4607 [==============================] - 392s 85ms/step - loss: 7.0292 - output_1_loss: 3.1385e-06 - output_2_loss: 0.3844 - output_3_loss: 0.0285 - output_4_loss: 6.1464 - output_3_precision_3: 0.8438 - output_3_recall_3: 0.5802 - output_3_true_negatives_3: 124251400.0000 - output_3_true_positives_3: 156172.0000 - output_3_false_negatives_3: 112998.0000 - output_3_false_positives_3: 28913.0000 - val_loss: 3.5767 - val_output_1_loss: 2.5204e-06 - val_output_2_loss: 0.2877 - val_output_3_loss: 0.0151 - val_output_4_loss: 2.9410 - val_output_3_precision_3: 0.9227 - val_output_3_recall_3: 0.8056 - val_output_3_true_negatives_3: 5057425.0000 - val_output_3_true_positives_3: 9490.0000 - val_output_3_false_negatives_3: 2290.0000 - val_output_3_false_positives_3: 795.0000
# Epoch 44/50
# 4607/4607 [==============================] - 390s 85ms/step - loss: 6.9735 - output_1_loss: 8.0913e-08 - output_2_loss: 0.3889 - output_3_loss: 0.0281 - output_4_loss: 6.0834 - output_3_precision_3: 0.8472 - output_3_recall_3: 0.5855 - output_3_true_negatives_3: 124252008.0000 - output_3_true_positives_3: 157563.0000 - output_3_false_negatives_3: 111567.0000 - output_3_false_positives_3: 28416.0000 - val_loss: 3.6038 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2854 - val_output_3_loss: 0.0153 - val_output_4_loss: 2.9716 - val_output_3_precision_3: 0.9039 - val_output_3_recall_3: 0.8142 - val_output_3_true_negatives_3: 5057200.0000 - val_output_3_true_positives_3: 9591.0000 - val_output_3_false_negatives_3: 2189.0000 - val_output_3_false_positives_3: 1020.0000
# Epoch 45/50
# 4607/4607 [==============================] - 398s 86ms/step - loss: 6.9646 - output_1_loss: 1.0030e-06 - output_2_loss: 0.3867 - output_3_loss: 0.0282 - output_4_loss: 6.0783 - output_3_precision_3: 0.8475 - output_3_recall_3: 0.5852 - output_3_true_negatives_3: 124252144.0000 - output_3_true_positives_3: 157518.0000 - output_3_false_negatives_3: 111654.0000 - output_3_false_positives_3: 28353.0000 - val_loss: 3.5282 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2946 - val_output_3_loss: 0.0146 - val_output_4_loss: 2.8805 - val_output_3_precision_3: 0.9125 - val_output_3_recall_3: 0.8202 - val_output_3_true_negatives_3: 5057293.0000 - val_output_3_true_positives_3: 9662.0000 - val_output_3_false_negatives_3: 2118.0000 - val_output_3_false_positives_3: 927.0000
# Epoch 46/50
# 4607/4607 [==============================] - 399s 87ms/step - loss: 6.8821 - output_1_loss: 4.5042e-07 - output_2_loss: 0.3819 - output_3_loss: 0.0278 - output_4_loss: 6.0070 - output_3_precision_3: 0.8493 - output_3_recall_3: 0.5906 - output_3_true_negatives_3: 124252632.0000 - output_3_true_positives_3: 158922.0000 - output_3_false_negatives_3: 110177.0000 - output_3_false_positives_3: 28196.0000 - val_loss: 3.4284 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2822 - val_output_3_loss: 0.0144 - val_output_4_loss: 2.8062 - val_output_3_precision_3: 0.9279 - val_output_3_recall_3: 0.8098 - val_output_3_true_negatives_3: 5057479.0000 - val_output_3_true_positives_3: 9539.0000 - val_output_3_false_negatives_3: 2241.0000 - val_output_3_false_positives_3: 741.0000
# Epoch 47/50
# 4607/4607 [==============================] - 396s 86ms/step - loss: 6.8381 - output_1_loss: 3.7041e-06 - output_2_loss: 0.3764 - output_3_loss: 0.0275 - output_4_loss: 5.9754 - output_3_precision_3: 0.8506 - output_3_recall_3: 0.5944 - output_3_true_negatives_3: 124252296.0000 - output_3_true_positives_3: 159957.0000 - output_3_false_negatives_3: 109147.0000 - output_3_false_positives_3: 28095.0000 - val_loss: 3.3877 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2820 - val_output_3_loss: 0.0142 - val_output_4_loss: 2.7669 - val_output_3_precision_3: 0.9157 - val_output_3_recall_3: 0.8333 - val_output_3_true_negatives_3: 5057316.0000 - val_output_3_true_positives_3: 9816.0000 - val_output_3_false_negatives_3: 1964.0000 - val_output_3_false_positives_3: 904.0000
# Epoch 48/50
# 4607/4607 [==============================] - 397s 86ms/step - loss: 6.7674 - output_1_loss: 2.0340e-06 - output_2_loss: 0.3790 - output_3_loss: 0.0272 - output_4_loss: 5.9007 - output_3_precision_3: 0.8528 - output_3_recall_3: 0.5995 - output_3_true_negatives_3: 124252552.0000 - output_3_true_positives_3: 161404.0000 - output_3_false_negatives_3: 107821.0000 - output_3_false_positives_3: 27854.0000 - val_loss: 3.3085 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2729 - val_output_3_loss: 0.0138 - val_output_4_loss: 2.7075 - val_output_3_precision_3: 0.9305 - val_output_3_recall_3: 0.8250 - val_output_3_true_negatives_3: 5057494.0000 - val_output_3_true_positives_3: 9719.0000 - val_output_3_false_negatives_3: 2061.0000 - val_output_3_false_positives_3: 726.0000
# Epoch 49/50
# 4607/4607 [==============================] - 393s 85ms/step - loss: 6.8069 - output_1_loss: 2.3895e-06 - output_2_loss: 0.3777 - output_3_loss: 0.0274 - output_4_loss: 5.9418 - output_3_precision_3: 0.8530 - output_3_recall_3: 0.5968 - output_3_true_negatives_3: 124252712.0000 - output_3_true_positives_3: 160643.0000 - output_3_false_negatives_3: 108513.0000 - output_3_false_positives_3: 27678.0000 - val_loss: 3.2335 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2817 - val_output_3_loss: 0.0134 - val_output_4_loss: 2.6166 - val_output_3_precision_3: 0.9260 - val_output_3_recall_3: 0.8324 - val_output_3_true_negatives_3: 5057436.0000 - val_output_3_true_positives_3: 9806.0000 - val_output_3_false_negatives_3: 1974.0000 - val_output_3_false_positives_3: 784.0000
# Epoch 50/50
# 4607/4607 [==============================] - 396s 86ms/step - loss: 6.7521 - output_1_loss: 1.1134e-09 - output_2_loss: 0.3777 - output_3_loss: 0.0272 - output_4_loss: 5.8877 - output_3_precision_3: 0.8549 - output_3_recall_3: 0.6017 - output_3_true_negatives_3: 124252976.0000 - output_3_true_positives_3: 161942.0000 - output_3_false_negatives_3: 107192.0000 - output_3_false_positives_3: 27477.0000 - val_loss: 3.2769 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2820 - val_output_3_loss: 0.0136 - val_output_4_loss: 2.6587 - val_output_3_precision_3: 0.9276 - val_output_3_recall_3: 0.8347 - val_output_3_true_negatives_3: 5057452.0000 - val_output_3_true_positives_3: 9833.0000 - val_output_3_false_negatives_3: 1947.0000 - val_output_3_false_positives_3: 768.0000

# %%
os.chdir("/home/sergio/Documents/json_experiments")
import json
#json.dumps(str(a))
with open('history_finetuning_1241_50_epoch_nadam_0dot0001_msle_exp_mse.json', 'w') as fp:
    json.dump(str(history.history), fp)

# %%
model.save_weights('/home/sergio/Documents/weights_saved/pesos_1241_50_epoch_nadam_0dot0001_msle_exp_mse')

# %% [markdown]
# ## Batch 16, con pesos 1,2,4,1 with lr=0.0001 y usando msle para el (x,y) y usando mse de las exponenciales para (w,h) SIGUIENTES 50 EPOCAS

# %%
anchors =tf.constant(np.array([[0.026,0.062],[0.067,0.183],[0.128,0.323],[0.343,0.650]]),dtype=tf.float32)
model = TinyYOLOv3(1,anchor_boxes=anchors,train=True,mode = "finetuning")
model.build(batch_input_shape=(None,416,416,3))
print(model.load_weights_darknet("/home/sergio/TinyYOLOv3-Pedestrian-Detection/yolov3-tiny.weights"))
model.load_weights('/home/sergio/Documents/weights_saved/pesos_1241_50_epoch_nadam_0dot0001_msle_exp_mse')
# Out:
# Pesos de la convolucion (432,)
# CONV SHAPE (16, 3, 3, 3)
# Pesos de la convolucion (4608,)
# CONV SHAPE (32, 16, 3, 3)
# Pesos de la convolucion (18432,)
# CONV SHAPE (64, 32, 3, 3)
# Pesos de la convolucion (73728,)
# CONV SHAPE (128, 64, 3, 3)
# Pesos de la convolucion (294912,)
# CONV SHAPE (256, 128, 3, 3)
# Pesos de la convolucion (1179648,)
# CONV SHAPE (512, 256, 3, 3)
# Pesos de la convolucion (4718592,)
# CONV SHAPE (1024, 512, 3, 3)
# Pesos de la convolucion (262144,)
# CONV SHAPE (256, 1024, 1, 1)
# Pesos de la convolucion (1179648,)
# CONV SHAPE (512, 256, 3, 3)
# Pesos de la convolucion (130560,)
# CONV SHAPE (255, 512, 1, 1)
# Pesos de la convolucion (32768,)
# CONV SHAPE (128, 256, 1, 1)
# Pesos de la convolucion (884736,)
# CONV SHAPE (256, 384, 3, 3)
# Pesos de la convolucion (65280,)
# CONV SHAPE (255, 256, 1, 1)
# 8858734

# %%
for l in model.layers:
    print(l.name, l.trainable)
    pass
# Out:
# BasicBlock1 True
# BasicBlock2 True
# BasicBlock3 True
# BasicBlock4 True
# BasicBlock5 True
# BasicBlock6 True
# BasicBlock7 True
# BasicBlock8 True
# BasicBlock9 True
# FinalBlock1 True
# BasicBlock11 True
# BasicBlock12 True
# FinalBlock2 True
# Concatenate True
# Upsampling True
# Prediction1 True
# Prediction2 True
# Concatenate_BBOX True

# %%
tf.random.set_seed(0)

from tensorflow.keras.metrics import TrueNegatives,TruePositives,FalseNegatives,FalsePositives,Precision,Recall

opt = tf.keras.optimizers.Nadam(learning_rate=1e-4)

losses = {"output_1": loss_xy,
          "output_2": loss_wh,
          "output_3":loss_objectness,
          "output_4":loss_no_objectness  
}

metrics = {"output_3":[Precision(),Recall(),TrueNegatives(),TruePositives(),FalseNegatives(),FalsePositives()]}
model.compile(optimizer=opt, loss=losses,metrics=metrics,loss_weights=[1,2,4,1])
os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")

# %% [markdown]
# ## Batch 16, con pesos 1,2,4,1 with lr=0.0001 y usando msle para el (x,y) y usando mse de las exponenciales para (w,h)

# %%
history = model.fit(train_dataset, epochs=20,validation_data=val_dataset)
# Out:
# Epoch 1/20
# 4607/4607 [==============================] - 550s 119ms/step - loss: 6.7411 - output_1_loss: 0.0000e+00 - output_2_loss: 0.3785 - output_3_loss: 0.0272 - output_4_loss: 5.8750 - output_3_precision: 0.8554 - output_3_recall: 0.6021 - output_3_true_negatives: 124252920.0000 - output_3_true_positives: 162087.0000 - output_3_false_negatives: 107120.0000 - output_3_false_positives: 27407.0000 - val_loss: 3.1314 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2714 - val_output_3_loss: 0.0129 - val_output_4_loss: 2.5370 - val_output_3_precision: 0.9284 - val_output_3_recall: 0.8447 - val_output_3_true_negatives: 5057453.0000 - val_output_3_true_positives: 9951.0000 - val_output_3_false_negatives: 1829.0000 - val_output_3_false_positives: 767.0000
# Epoch 2/20
# 4607/4607 [==============================] - 534s 116ms/step - loss: 6.6913 - output_1_loss: 3.8509e-07 - output_2_loss: 0.3775 - output_3_loss: 0.0270 - output_4_loss: 5.8285 - output_3_precision: 0.8586 - output_3_recall: 0.6058 - output_3_true_negatives: 124253568.0000 - output_3_true_positives: 163087.0000 - output_3_false_negatives: 106117.0000 - output_3_false_positives: 26852.0000 - val_loss: 3.1384 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2793 - val_output_3_loss: 0.0128 - val_output_4_loss: 2.5288 - val_output_3_precision: 0.9211 - val_output_3_recall: 0.8524 - val_output_3_true_negatives: 5057360.0000 - val_output_3_true_positives: 10041.0000 - val_output_3_false_negatives: 1739.0000 - val_output_3_false_positives: 860.0000
# Epoch 3/20
# 4607/4607 [==============================] - 539s 117ms/step - loss: 6.6360 - output_1_loss: 1.6540e-07 - output_2_loss: 0.3801 - output_3_loss: 0.0266 - output_4_loss: 5.7693 - output_3_precision: 0.8605 - output_3_recall: 0.6117 - output_3_true_negatives: 124253712.0000 - output_3_true_positives: 164628.0000 - output_3_false_negatives: 104510.0000 - output_3_false_positives: 26691.0000 - val_loss: 3.0361 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2827 - val_output_3_loss: 0.0123 - val_output_4_loss: 2.4212 - val_output_3_precision: 0.9363 - val_output_3_recall: 0.8402 - val_output_3_true_negatives: 5057547.0000 - val_output_3_true_positives: 9897.0000 - val_output_3_false_negatives: 1883.0000 - val_output_3_false_positives: 673.0000
# Epoch 4/20
# 4607/4607 [==============================] - 556s 121ms/step - loss: 6.6599 - output_1_loss: 1.5246e-07 - output_2_loss: 0.3789 - output_3_loss: 0.0268 - output_4_loss: 5.7947 - output_3_precision: 0.8591 - output_3_recall: 0.6088 - output_3_true_negatives: 124253736.0000 - output_3_true_positives: 163867.0000 - output_3_false_negatives: 105301.0000 - output_3_false_positives: 26866.0000 - val_loss: 2.9941 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2730 - val_output_3_loss: 0.0124 - val_output_4_loss: 2.3987 - val_output_3_precision: 0.9365 - val_output_3_recall: 0.8387 - val_output_3_true_negatives: 5057550.0000 - val_output_3_true_positives: 9880.0000 - val_output_3_false_negatives: 1900.0000 - val_output_3_false_positives: 670.0000
# Epoch 5/20
# 4607/4607 [==============================] - 553s 120ms/step - loss: 6.6236 - output_1_loss: 1.0860e-06 - output_2_loss: 0.3751 - output_3_loss: 0.0267 - output_4_loss: 5.7666 - output_3_precision: 0.8617 - output_3_recall: 0.6126 - output_3_true_negatives: 124254184.0000 - output_3_true_positives: 164902.0000 - output_3_false_negatives: 104301.0000 - output_3_false_positives: 26476.0000 - val_loss: 2.9256 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2765 - val_output_3_loss: 0.0118 - val_output_4_loss: 2.3253 - val_output_3_precision: 0.9304 - val_output_3_recall: 0.8678 - val_output_3_true_negatives: 5057455.0000 - val_output_3_true_positives: 10223.0000 - val_output_3_false_negatives: 1557.0000 - val_output_3_false_positives: 765.0000
# Epoch 6/20
# 4607/4607 [==============================] - 542s 118ms/step - loss: 6.5257 - output_1_loss: 2.6094e-07 - output_2_loss: 0.3681 - output_3_loss: 0.0262 - output_4_loss: 5.6849 - output_3_precision: 0.8630 - output_3_recall: 0.6176 - output_3_true_negatives: 124254216.0000 - output_3_true_positives: 166224.0000 - output_3_false_negatives: 102914.0000 - output_3_false_positives: 26395.0000 - val_loss: 2.9225 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2743 - val_output_3_loss: 0.0118 - val_output_4_loss: 2.3267 - val_output_3_precision: 0.9221 - val_output_3_recall: 0.8767 - val_output_3_true_negatives: 5057347.0000 - val_output_3_true_positives: 10328.0000 - val_output_3_false_negatives: 1452.0000 - val_output_3_false_positives: 873.0000
# Epoch 7/20
# 4607/4607 [==============================] - 549s 119ms/step - loss: 6.5263 - output_1_loss: 5.5796e-07 - output_2_loss: 0.3735 - output_3_loss: 0.0262 - output_4_loss: 5.6746 - output_3_precision: 0.8629 - output_3_recall: 0.6201 - output_3_true_negatives: 124253992.0000 - output_3_true_positives: 166898.0000 - output_3_false_negatives: 102267.0000 - output_3_false_positives: 26517.0000 - val_loss: 2.8878 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2665 - val_output_3_loss: 0.0119 - val_output_4_loss: 2.3072 - val_output_3_precision: 0.9424 - val_output_3_recall: 0.8499 - val_output_3_true_negatives: 5057608.0000 - val_output_3_true_positives: 10012.0000 - val_output_3_false_negatives: 1768.0000 - val_output_3_false_positives: 612.0000
# Epoch 8/20
# 4607/4607 [==============================] - 554s 120ms/step - loss: 6.4911 - output_1_loss: 4.1658e-06 - output_2_loss: 0.3625 - output_3_loss: 0.0261 - output_4_loss: 5.6617 - output_3_precision: 0.8619 - output_3_recall: 0.6186 - output_3_true_negatives: 124253936.0000 - output_3_true_positives: 166417.0000 - output_3_false_negatives: 102594.0000 - output_3_false_positives: 26656.0000 - val_loss: 2.7976 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2616 - val_output_3_loss: 0.0111 - val_output_4_loss: 2.2298 - val_output_3_precision: 0.9362 - val_output_3_recall: 0.8699 - val_output_3_true_negatives: 5057522.0000 - val_output_3_true_positives: 10248.0000 - val_output_3_false_negatives: 1532.0000 - val_output_3_false_positives: 698.0000
# Epoch 9/20
# 4607/4607 [==============================] - 541s 118ms/step - loss: 6.4702 - output_1_loss: 1.1211e-07 - output_2_loss: 0.3658 - output_3_loss: 0.0261 - output_4_loss: 5.6344 - output_3_precision: 0.8662 - output_3_recall: 0.6230 - output_3_true_negatives: 124254680.0000 - output_3_true_positives: 167672.0000 - output_3_false_negatives: 101480.0000 - output_3_false_positives: 25903.0000 - val_loss: 2.8382 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2701 - val_output_3_loss: 0.0113 - val_output_4_loss: 2.2527 - val_output_3_precision: 0.9378 - val_output_3_recall: 0.8607 - val_output_3_true_negatives: 5057547.0000 - val_output_3_true_positives: 10139.0000 - val_output_3_false_negatives: 1641.0000 - val_output_3_false_positives: 673.0000
# Epoch 10/20
# 4607/4607 [==============================] - 558s 121ms/step - loss: 6.3615 - output_1_loss: 3.0367e-08 - output_2_loss: 0.3626 - output_3_loss: 0.0255 - output_4_loss: 5.5342 - output_3_precision: 0.8672 - output_3_recall: 0.6288 - output_3_true_negatives: 124254472.0000 - output_3_true_positives: 169274.0000 - output_3_false_negatives: 99933.0000 - output_3_false_positives: 25916.0000 - val_loss: 2.6023 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2602 - val_output_3_loss: 0.0105 - val_output_4_loss: 2.0400 - val_output_3_precision: 0.9495 - val_output_3_recall: 0.8703 - val_output_3_true_negatives: 5057675.0000 - val_output_3_true_positives: 10252.0000 - val_output_3_false_negatives: 1528.0000 - val_output_3_false_positives: 545.0000
# Epoch 11/20
# 4607/4607 [==============================] - 544s 118ms/step - loss: 6.4460 - output_1_loss: 1.7376e-06 - output_2_loss: 0.3683 - output_3_loss: 0.0259 - output_4_loss: 5.6058 - output_3_precision: 0.8670 - output_3_recall: 0.6238 - output_3_true_negatives: 124254632.0000 - output_3_true_positives: 167942.0000 - output_3_false_negatives: 101261.0000 - output_3_false_positives: 25765.0000 - val_loss: 2.7891 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2710 - val_output_3_loss: 0.0111 - val_output_4_loss: 2.2026 - val_output_3_precision: 0.9428 - val_output_3_recall: 0.8662 - val_output_3_true_negatives: 5057601.0000 - val_output_3_true_positives: 10204.0000 - val_output_3_false_negatives: 1576.0000 - val_output_3_false_positives: 619.0000
# Epoch 12/20
# 4607/4607 [==============================] - 544s 118ms/step - loss: 6.3674 - output_1_loss: 3.2157e-07 - output_2_loss: 0.3590 - output_3_loss: 0.0256 - output_4_loss: 5.5471 - output_3_precision: 0.8675 - output_3_recall: 0.6286 - output_3_true_negatives: 124254664.0000 - output_3_true_positives: 169186.0000 - output_3_false_negatives: 99962.0000 - output_3_false_positives: 25832.0000 - val_loss: 2.6036 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2537 - val_output_3_loss: 0.0104 - val_output_4_loss: 2.0547 - val_output_3_precision: 0.9453 - val_output_3_recall: 0.8807 - val_output_3_true_negatives: 5057620.0000 - val_output_3_true_positives: 10375.0000 - val_output_3_false_negatives: 1405.0000 - val_output_3_false_positives: 600.0000
# Epoch 13/20
# 4607/4607 [==============================] - 559s 121ms/step - loss: 6.3369 - output_1_loss: 0.0000e+00 - output_2_loss: 0.3560 - output_3_loss: 0.0255 - output_4_loss: 5.5229 - output_3_precision: 0.8701 - output_3_recall: 0.6315 - output_3_true_negatives: 124255120.0000 - output_3_true_positives: 169962.0000 - output_3_false_negatives: 99161.0000 - output_3_false_positives: 25375.0000 - val_loss: 2.6158 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2540 - val_output_3_loss: 0.0104 - val_output_4_loss: 2.0660 - val_output_3_precision: 0.9412 - val_output_3_recall: 0.8811 - val_output_3_true_negatives: 5057572.0000 - val_output_3_true_positives: 10379.0000 - val_output_3_false_negatives: 1401.0000 - val_output_3_false_positives: 648.0000
# Epoch 14/20
# 4607/4607 [==============================] - 542s 118ms/step - loss: 6.3882 - output_1_loss: 6.1238e-07 - output_2_loss: 0.3683 - output_3_loss: 0.0256 - output_4_loss: 5.5494 - output_3_precision: 0.8705 - output_3_recall: 0.6283 - output_3_true_negatives: 124255560.0000 - output_3_true_positives: 169109.0000 - output_3_false_negatives: 100023.0000 - output_3_false_positives: 25164.0000 - val_loss: 2.6458 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2570 - val_output_3_loss: 0.0106 - val_output_4_loss: 2.0896 - val_output_3_precision: 0.9384 - val_output_3_recall: 0.8887 - val_output_3_true_negatives: 5057533.0000 - val_output_3_true_positives: 10469.0000 - val_output_3_false_negatives: 1311.0000 - val_output_3_false_positives: 687.0000
# Epoch 15/20
# 4607/4607 [==============================] - 508s 110ms/step - loss: 6.2633 - output_1_loss: 1.3534e-06 - output_2_loss: 0.3567 - output_3_loss: 0.0250 - output_4_loss: 5.4499 - output_3_precision: 0.8718 - output_3_recall: 0.6367 - output_3_true_negatives: 124255264.0000 - output_3_true_positives: 171304.0000 - output_3_false_negatives: 97754.0000 - output_3_false_positives: 25190.0000 - val_loss: 2.6583 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2550 - val_output_3_loss: 0.0105 - val_output_4_loss: 2.1062 - val_output_3_precision: 0.9419 - val_output_3_recall: 0.8824 - val_output_3_true_negatives: 5057579.0000 - val_output_3_true_positives: 10395.0000 - val_output_3_false_negatives: 1385.0000 - val_output_3_false_positives: 641.0000
# Epoch 16/20
# 4607/4607 [==============================] - 496s 108ms/step - loss: 6.2415 - output_1_loss: 7.0952e-07 - output_2_loss: 0.3559 - output_3_loss: 0.0251 - output_4_loss: 5.4294 - output_3_precision: 0.8723 - output_3_recall: 0.6382 - output_3_true_negatives: 124255392.0000 - output_3_true_positives: 171781.0000 - output_3_false_negatives: 97385.0000 - output_3_false_positives: 25143.0000 - val_loss: 2.6651 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2532 - val_output_3_loss: 0.0107 - val_output_4_loss: 2.1158 - val_output_3_precision: 0.9573 - val_output_3_recall: 0.8624 - val_output_3_true_negatives: 5057767.0000 - val_output_3_true_positives: 10159.0000 - val_output_3_false_negatives: 1621.0000 - val_output_3_false_positives: 453.0000
# Epoch 17/20
# 4607/4607 [==============================] - 502s 109ms/step - loss: 6.2403 - output_1_loss: 2.6595e-07 - output_2_loss: 0.3559 - output_3_loss: 0.0250 - output_4_loss: 5.4286 - output_3_precision: 0.8735 - output_3_recall: 0.6382 - output_3_true_negatives: 124255776.0000 - output_3_true_positives: 171703.0000 - output_3_false_negatives: 97345.0000 - output_3_false_positives: 24863.0000 - val_loss: 2.5748 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2641 - val_output_3_loss: 0.0100 - val_output_4_loss: 2.0065 - val_output_3_precision: 0.9568 - val_output_3_recall: 0.8735 - val_output_3_true_negatives: 5057755.0000 - val_output_3_true_positives: 10290.0000 - val_output_3_false_negatives: 1490.0000 - val_output_3_false_positives: 465.0000
# Epoch 18/20
# 4607/4607 [==============================] - 502s 109ms/step - loss: 6.2212 - output_1_loss: 3.6756e-06 - output_2_loss: 0.3621 - output_3_loss: 0.0248 - output_4_loss: 5.3980 - output_3_precision: 0.8743 - output_3_recall: 0.6406 - output_3_true_negatives: 124255784.0000 - output_3_true_positives: 172378.0000 - output_3_false_negatives: 96730.0000 - output_3_false_positives: 24784.0000 - val_loss: 2.4619 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2446 - val_output_3_loss: 0.0096 - val_output_4_loss: 1.9344 - val_output_3_precision: 0.9513 - val_output_3_recall: 0.8895 - val_output_3_true_negatives: 5057684.0000 - val_output_3_true_positives: 10478.0000 - val_output_3_false_negatives: 1302.0000 - val_output_3_false_positives: 536.0000
# Epoch 19/20
# 4607/4607 [==============================] - 518s 113ms/step - loss: 6.1510 - output_1_loss: 3.1861e-06 - output_2_loss: 0.3483 - output_3_loss: 0.0245 - output_4_loss: 5.3564 - output_3_precision: 0.8750 - output_3_recall: 0.6439 - output_3_true_negatives: 124255696.0000 - output_3_true_positives: 173282.0000 - output_3_false_negatives: 95846.0000 - output_3_false_positives: 24750.0000 - val_loss: 2.4511 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2475 - val_output_3_loss: 0.0095 - val_output_4_loss: 1.9180 - val_output_3_precision: 0.9567 - val_output_3_recall: 0.8796 - val_output_3_true_negatives: 5057751.0000 - val_output_3_true_positives: 10362.0000 - val_output_3_false_negatives: 1418.0000 - val_output_3_false_positives: 469.0000
# Epoch 20/20
# 4607/4607 [==============================] - 508s 110ms/step - loss: 6.1317 - output_1_loss: 1.5026e-06 - output_2_loss: 0.3479 - output_3_loss: 0.0244 - output_4_loss: 5.3383 - output_3_precision: 0.8757 - output_3_recall: 0.6448 - output_3_true_negatives: 124255712.0000 - output_3_true_positives: 173544.0000 - output_3_false_negatives: 95610.0000 - output_3_false_positives: 24623.0000 - val_loss: 2.4403 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2536 - val_output_3_loss: 0.0096 - val_output_4_loss: 1.8948 - val_output_3_precision: 0.9556 - val_output_3_recall: 0.8791 - val_output_3_true_negatives: 5057739.0000 - val_output_3_true_positives: 10356.0000 - val_output_3_false_negatives: 1424.0000 - val_output_3_false_positives: 481.0000

# %%
os.chdir("/home/sergio/Documents/json_experiments")
import json
#json.dumps(str(a))
with open('history_finetuning_1241_50_to_70_epoch_nadam_0dot0001_msle_exp_mse.json', 'w') as fp:
    json.dump(str(history.history), fp)

# %%
model.save_weights('/home/sergio/Documents/weights_saved/pesos_1241_50_to_70_epoch_nadam_0dot0001_msle_exp_mse')

# %% [markdown]
# ### 20 epocas con msle y exp de mse, 20 epocas y con pesos 1441 y con lr = 1e-5

# %%
tf.random.set_seed(0)

from tensorflow.keras.metrics import TrueNegatives,TruePositives,FalseNegatives,FalsePositives,Precision,Recall

opt = tf.keras.optimizers.Nadam(learning_rate=1e-5)

losses = {"output_1": loss_xy,
          "output_2": loss_wh,
          "output_3":loss_objectness,
          "output_4":loss_no_objectness  
}

metrics = {"output_3":[Precision(),Recall(),TrueNegatives(),TruePositives(),FalseNegatives(),FalsePositives()]}
model.compile(optimizer=opt, loss=losses,metrics=metrics,loss_weights=[1,4,4,1])
os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")

# %%
history = model.fit(train_dataset, epochs=20,validation_data=val_dataset)
# Out:
# Epoch 1/20
# 4607/4607 [==============================] - 541s 117ms/step - loss: 6.5949 - output_1_loss: 3.8542e-06 - output_2_loss: 0.3365 - output_3_loss: 0.0237 - output_4_loss: 5.1538 - output_3_precision_1: 0.8839 - output_3_recall_1: 0.6559 - output_3_true_negatives_1: 124257408.0000 - output_3_true_positives_1: 176540.0000 - output_3_false_negatives_1: 92625.0000 - output_3_false_positives_1: 23191.0000 - val_loss: 2.2907 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2207 - val_output_3_loss: 0.0070 - val_output_4_loss: 1.3802 - val_output_3_precision_1: 0.9693 - val_output_3_recall_1: 0.9342 - val_output_3_true_negatives_1: 5057872.0000 - val_output_3_true_positives_1: 11005.0000 - val_output_3_false_negatives_1: 775.0000 - val_output_3_false_positives_1: 348.0000
# Epoch 2/20
# 4607/4607 [==============================] - 539s 117ms/step - loss: 6.3456 - output_1_loss: 0.0000e+00 - output_2_loss: 0.3260 - output_3_loss: 0.0226 - output_4_loss: 4.9509 - output_3_precision_1: 0.8911 - output_3_recall_1: 0.6708 - output_3_true_negatives_1: 124258336.0000 - output_3_true_positives_1: 180531.0000 - output_3_false_negatives_1: 88578.0000 - output_3_false_positives_1: 22064.0000 - val_loss: 2.1654 - val_output_1_loss: 2.0855e-06 - val_output_2_loss: 0.2176 - val_output_3_loss: 0.0064 - val_output_4_loss: 1.2693 - val_output_3_precision_1: 0.9761 - val_output_3_recall_1: 0.9407 - val_output_3_true_negatives_1: 5057949.0000 - val_output_3_true_positives_1: 11082.0000 - val_output_3_false_negatives_1: 698.0000 - val_output_3_false_positives_1: 271.0000
# Epoch 3/20
# 4607/4607 [==============================] - 532s 115ms/step - loss: 6.2488 - output_1_loss: 1.6227e-10 - output_2_loss: 0.3147 - output_3_loss: 0.0224 - output_4_loss: 4.9003 - output_3_precision_1: 0.8935 - output_3_recall_1: 0.6754 - output_3_true_negatives_1: 124258704.0000 - output_3_true_positives_1: 181795.0000 - output_3_false_negatives_1: 87385.0000 - output_3_false_positives_1: 21661.0000 - val_loss: 2.0812 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2108 - val_output_3_loss: 0.0061 - val_output_4_loss: 1.2135 - val_output_3_precision_1: 0.9762 - val_output_3_recall_1: 0.9459 - val_output_3_true_negatives_1: 5057948.0000 - val_output_3_true_positives_1: 11143.0000 - val_output_3_false_negatives_1: 637.0000 - val_output_3_false_positives_1: 272.0000
# Epoch 4/20
# 4607/4607 [==============================] - 523s 114ms/step - loss: 6.1980 - output_1_loss: 5.6713e-07 - output_2_loss: 0.3137 - output_3_loss: 0.0223 - output_4_loss: 4.8541 - output_3_precision_1: 0.8947 - output_3_recall_1: 0.6782 - output_3_true_negatives_1: 124258984.0000 - output_3_true_positives_1: 182528.0000 - output_3_false_negatives_1: 86625.0000 - output_3_false_positives_1: 21489.0000 - val_loss: 2.0047 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2088 - val_output_3_loss: 0.0058 - val_output_4_loss: 1.1464 - val_output_3_precision_1: 0.9794 - val_output_3_recall_1: 0.9487 - val_output_3_true_negatives_1: 5057985.0000 - val_output_3_true_positives_1: 11176.0000 - val_output_3_false_negatives_1: 604.0000 - val_output_3_false_positives_1: 235.0000
# Epoch 5/20
# 4607/4607 [==============================] - 544s 118ms/step - loss: 6.2117 - output_1_loss: 0.0000e+00 - output_2_loss: 0.3159 - output_3_loss: 0.0224 - output_4_loss: 4.8587 - output_3_precision_1: 0.8969 - output_3_recall_1: 0.6792 - output_3_true_negatives_1: 124259568.0000 - output_3_true_positives_1: 182746.0000 - output_3_false_negatives_1: 86332.0000 - output_3_false_positives_1: 20996.0000 - val_loss: 1.9491 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.2048 - val_output_3_loss: 0.0056 - val_output_4_loss: 1.1075 - val_output_3_precision_1: 0.9801 - val_output_3_recall_1: 0.9530 - val_output_3_true_negatives_1: 5057992.0000 - val_output_3_true_positives_1: 11226.0000 - val_output_3_false_negatives_1: 554.0000 - val_output_3_false_positives_1: 228.0000
# Epoch 6/20
# 4607/4607 [==============================] - 542s 118ms/step - loss: 6.2131 - output_1_loss: 4.2698e-06 - output_2_loss: 0.3163 - output_3_loss: 0.0224 - output_4_loss: 4.8585 - output_3_precision_1: 0.8971 - output_3_recall_1: 0.6791 - output_3_true_negatives_1: 124259536.0000 - output_3_true_positives_1: 182768.0000 - output_3_false_negatives_1: 86348.0000 - output_3_false_positives_1: 20975.0000 - val_loss: 1.9066 - val_output_1_loss: 5.8596e-07 - val_output_2_loss: 0.2010 - val_output_3_loss: 0.0055 - val_output_4_loss: 1.0807 - val_output_3_precision_1: 0.9805 - val_output_3_recall_1: 0.9569 - val_output_3_true_negatives_1: 5057996.0000 - val_output_3_true_positives_1: 11272.0000 - val_output_3_false_negatives_1: 508.0000 - val_output_3_false_positives_1: 224.0000
# Epoch 7/20
# 4607/4607 [==============================] - 549s 119ms/step - loss: 6.1171 - output_1_loss: 4.0978e-08 - output_2_loss: 0.3118 - output_3_loss: 0.0221 - output_4_loss: 4.7813 - output_3_precision_1: 0.8996 - output_3_recall_1: 0.6832 - output_3_true_negatives_1: 124260072.0000 - output_3_true_positives_1: 183850.0000 - output_3_false_negatives_1: 85253.0000 - output_3_false_positives_1: 20522.0000 - val_loss: 1.8660 - val_output_1_loss: 3.2038e-06 - val_output_2_loss: 0.1993 - val_output_3_loss: 0.0053 - val_output_4_loss: 1.0475 - val_output_3_precision_1: 0.9824 - val_output_3_recall_1: 0.9597 - val_output_3_true_negatives_1: 5058017.0000 - val_output_3_true_positives_1: 11305.0000 - val_output_3_false_negatives_1: 475.0000 - val_output_3_false_positives_1: 203.0000
# Epoch 8/20
# 4607/4607 [==============================] - 546s 119ms/step - loss: 6.1283 - output_1_loss: 2.6377e-06 - output_2_loss: 0.3171 - output_3_loss: 0.0220 - output_4_loss: 4.7718 - output_3_precision_1: 0.8993 - output_3_recall_1: 0.6839 - output_3_true_negatives_1: 124260024.0000 - output_3_true_positives_1: 184044.0000 - output_3_false_negatives_1: 85080.0000 - output_3_false_positives_1: 20601.0000 - val_loss: 1.8391 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1990 - val_output_3_loss: 0.0052 - val_output_4_loss: 1.0222 - val_output_3_precision_1: 0.9828 - val_output_3_recall_1: 0.9616 - val_output_3_true_negatives_1: 5058022.0000 - val_output_3_true_positives_1: 11328.0000 - val_output_3_false_negatives_1: 452.0000 - val_output_3_false_positives_1: 198.0000
# Epoch 9/20
# 4607/4607 [==============================] - 548s 119ms/step - loss: 6.0683 - output_1_loss: 7.3169e-06 - output_2_loss: 0.3091 - output_3_loss: 0.0218 - output_4_loss: 4.7445 - output_3_precision_1: 0.9003 - output_3_recall_1: 0.6863 - output_3_true_negatives_1: 124260040.0000 - output_3_true_positives_1: 184655.0000 - output_3_false_negatives_1: 84392.0000 - output_3_false_positives_1: 20450.0000 - val_loss: 1.8155 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1975 - val_output_3_loss: 0.0051 - val_output_4_loss: 1.0052 - val_output_3_precision_1: 0.9833 - val_output_3_recall_1: 0.9607 - val_output_3_true_negatives_1: 5058028.0000 - val_output_3_true_positives_1: 11317.0000 - val_output_3_false_negatives_1: 463.0000 - val_output_3_false_positives_1: 192.0000
# Epoch 10/20
# 4607/4607 [==============================] - 533s 116ms/step - loss: 6.0543 - output_1_loss: 2.8264e-06 - output_2_loss: 0.2996 - output_3_loss: 0.0220 - output_4_loss: 4.7679 - output_3_precision_1: 0.9012 - output_3_recall_1: 0.6840 - output_3_true_negatives_1: 124260296.0000 - output_3_true_positives_1: 184073.0000 - output_3_false_negatives_1: 85040.0000 - output_3_false_positives_1: 20189.0000 - val_loss: 1.8000 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1941 - val_output_3_loss: 0.0051 - val_output_4_loss: 1.0033 - val_output_3_precision_1: 0.9831 - val_output_3_recall_1: 0.9653 - val_output_3_true_negatives_1: 5058025.0000 - val_output_3_true_positives_1: 11371.0000 - val_output_3_false_negatives_1: 409.0000 - val_output_3_false_positives_1: 195.0000
# Epoch 11/20
# 4607/4607 [==============================] - 548s 119ms/step - loss: 5.9886 - output_1_loss: 2.3243e-07 - output_2_loss: 0.3020 - output_3_loss: 0.0216 - output_4_loss: 4.6942 - output_3_precision_1: 0.9026 - output_3_recall_1: 0.6898 - output_3_true_negatives_1: 124260320.0000 - output_3_true_positives_1: 185666.0000 - output_3_false_negatives_1: 83495.0000 - output_3_false_positives_1: 20031.0000 - val_loss: 1.7823 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1934 - val_output_3_loss: 0.0050 - val_output_4_loss: 0.9887 - val_output_3_precision_1: 0.9834 - val_output_3_recall_1: 0.9655 - val_output_3_true_negatives_1: 5058028.0000 - val_output_3_true_positives_1: 11374.0000 - val_output_3_false_negatives_1: 406.0000 - val_output_3_false_positives_1: 192.0000
# Epoch 12/20
# 4607/4607 [==============================] - 550s 119ms/step - loss: 5.9849 - output_1_loss: 1.3724e-08 - output_2_loss: 0.3010 - output_3_loss: 0.0217 - output_4_loss: 4.6942 - output_3_precision_1: 0.9010 - output_3_recall_1: 0.6877 - output_3_true_negatives_1: 124260256.0000 - output_3_true_positives_1: 185045.0000 - output_3_false_negatives_1: 84051.0000 - output_3_false_positives_1: 20330.0000 - val_loss: 1.7526 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1928 - val_output_3_loss: 0.0049 - val_output_4_loss: 0.9620 - val_output_3_precision_1: 0.9847 - val_output_3_recall_1: 0.9663 - val_output_3_true_negatives_1: 5058043.0000 - val_output_3_true_positives_1: 11383.0000 - val_output_3_false_negatives_1: 397.0000 - val_output_3_false_positives_1: 177.0000
# Epoch 13/20
# 4607/4607 [==============================] - 558s 121ms/step - loss: 6.0213 - output_1_loss: 3.3048e-06 - output_2_loss: 0.3076 - output_3_loss: 0.0217 - output_4_loss: 4.7042 - output_3_precision_1: 0.9021 - output_3_recall_1: 0.6881 - output_3_true_negatives_1: 124260408.0000 - output_3_true_positives_1: 185193.0000 - output_3_false_negatives_1: 83933.0000 - output_3_false_positives_1: 20089.0000 - val_loss: 1.7634 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1913 - val_output_3_loss: 0.0050 - val_output_4_loss: 0.9782 - val_output_3_precision_1: 0.9844 - val_output_3_recall_1: 0.9674 - val_output_3_true_negatives_1: 5058039.0000 - val_output_3_true_positives_1: 11396.0000 - val_output_3_false_negatives_1: 384.0000 - val_output_3_false_positives_1: 181.0000
# Epoch 14/20
# 4607/4607 [==============================] - 540s 117ms/step - loss: 5.9689 - output_1_loss: 2.3804e-07 - output_2_loss: 0.2989 - output_3_loss: 0.0216 - output_4_loss: 4.6867 - output_3_precision_1: 0.9030 - output_3_recall_1: 0.6914 - output_3_true_negatives_1: 124260600.0000 - output_3_true_positives_1: 186048.0000 - output_3_false_negatives_1: 83040.0000 - output_3_false_positives_1: 19984.0000 - val_loss: 1.7153 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1903 - val_output_3_loss: 0.0048 - val_output_4_loss: 0.9353 - val_output_3_precision_1: 0.9852 - val_output_3_recall_1: 0.9679 - val_output_3_true_negatives_1: 5058049.0000 - val_output_3_true_positives_1: 11402.0000 - val_output_3_false_negatives_1: 378.0000 - val_output_3_false_positives_1: 171.0000
# Epoch 15/20
# 4607/4607 [==============================] - 548s 119ms/step - loss: 5.9712 - output_1_loss: 3.4875e-06 - output_2_loss: 0.2966 - output_3_loss: 0.0217 - output_4_loss: 4.6982 - output_3_precision_1: 0.9015 - output_3_recall_1: 0.6883 - output_3_true_negatives_1: 124260416.0000 - output_3_true_positives_1: 185241.0000 - output_3_false_negatives_1: 83906.0000 - output_3_false_positives_1: 20232.0000 - val_loss: 1.7066 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1881 - val_output_3_loss: 0.0047 - val_output_4_loss: 0.9354 - val_output_3_precision_1: 0.9853 - val_output_3_recall_1: 0.9677 - val_output_3_true_negatives_1: 5058050.0000 - val_output_3_true_positives_1: 11399.0000 - val_output_3_false_negatives_1: 381.0000 - val_output_3_false_positives_1: 170.0000
# Epoch 16/20
# 4607/4607 [==============================] - 556s 121ms/step - loss: 5.9659 - output_1_loss: 1.1681e-05 - output_2_loss: 0.3009 - output_3_loss: 0.0215 - output_4_loss: 4.6762 - output_3_precision_1: 0.9037 - output_3_recall_1: 0.6906 - output_3_true_negatives_1: 124260688.0000 - output_3_true_positives_1: 185764.0000 - output_3_false_negatives_1: 83240.0000 - output_3_false_positives_1: 19789.0000 - val_loss: 1.7118 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1875 - val_output_3_loss: 0.0048 - val_output_4_loss: 0.9427 - val_output_3_precision_1: 0.9863 - val_output_3_recall_1: 0.9708 - val_output_3_true_negatives_1: 5058061.0000 - val_output_3_true_positives_1: 11436.0000 - val_output_3_false_negatives_1: 344.0000 - val_output_3_false_positives_1: 159.0000
# Epoch 17/20
# 4607/4607 [==============================] - 555s 121ms/step - loss: 5.9337 - output_1_loss: 7.7675e-06 - output_2_loss: 0.3006 - output_3_loss: 0.0213 - output_4_loss: 4.6460 - output_3_precision_1: 0.9036 - output_3_recall_1: 0.6932 - output_3_true_negatives_1: 124260296.0000 - output_3_true_positives_1: 186574.0000 - output_3_false_negatives_1: 82584.0000 - output_3_false_positives_1: 19903.0000 - val_loss: 1.6735 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1873 - val_output_3_loss: 0.0046 - val_output_4_loss: 0.9060 - val_output_3_precision_1: 0.9866 - val_output_3_recall_1: 0.9708 - val_output_3_true_negatives_1: 5058065.0000 - val_output_3_true_positives_1: 11436.0000 - val_output_3_false_negatives_1: 344.0000 - val_output_3_false_positives_1: 155.0000
# Epoch 18/20
# 4607/4607 [==============================] - 537s 117ms/step - loss: 5.9333 - output_1_loss: 1.2072e-06 - output_2_loss: 0.2964 - output_3_loss: 0.0215 - output_4_loss: 4.6619 - output_3_precision_1: 0.9028 - output_3_recall_1: 0.6912 - output_3_true_negatives_1: 124260472.0000 - output_3_true_positives_1: 186012.0000 - output_3_false_negatives_1: 83120.0000 - output_3_false_positives_1: 20018.0000 - val_loss: 1.6663 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1850 - val_output_3_loss: 0.0046 - val_output_4_loss: 0.9080 - val_output_3_precision_1: 0.9861 - val_output_3_recall_1: 0.9722 - val_output_3_true_negatives_1: 5058058.0000 - val_output_3_true_positives_1: 11452.0000 - val_output_3_false_negatives_1: 328.0000 - val_output_3_false_positives_1: 162.0000
# Epoch 19/20
# 4607/4607 [==============================] - 561s 122ms/step - loss: 5.8800 - output_1_loss: 1.5765e-05 - output_2_loss: 0.2956 - output_3_loss: 0.0213 - output_4_loss: 4.6124 - output_3_precision_1: 0.9054 - output_3_recall_1: 0.6946 - output_3_true_negatives_1: 124260880.0000 - output_3_true_positives_1: 186995.0000 - output_3_false_negatives_1: 82206.0000 - output_3_false_positives_1: 19533.0000 - val_loss: 1.6503 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1856 - val_output_3_loss: 0.0045 - val_output_4_loss: 0.8898 - val_output_3_precision_1: 0.9865 - val_output_3_recall_1: 0.9699 - val_output_3_true_negatives_1: 5058064.0000 - val_output_3_true_positives_1: 11425.0000 - val_output_3_false_negatives_1: 355.0000 - val_output_3_false_positives_1: 156.0000
# Epoch 20/20
# 4607/4607 [==============================] - 548s 119ms/step - loss: 5.8492 - output_1_loss: 1.8657e-07 - output_2_loss: 0.2893 - output_3_loss: 0.0212 - output_4_loss: 4.6071 - output_3_precision_1: 0.9042 - output_3_recall_1: 0.6950 - output_3_true_negatives_1: 124260592.0000 - output_3_true_positives_1: 187009.0000 - output_3_false_negatives_1: 82051.0000 - output_3_false_positives_1: 19805.0000 - val_loss: 1.6402 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1838 - val_output_3_loss: 0.0045 - val_output_4_loss: 0.8870 - val_output_3_precision_1: 0.9864 - val_output_3_recall_1: 0.9720 - val_output_3_true_negatives_1: 5058062.0000 - val_output_3_true_positives_1: 11450.0000 - val_output_3_false_negatives_1: 330.0000 - val_output_3_false_positives_1: 158.0000

# %%
os.chdir("/home/sergio/Documents/json_experiments")
import json
#json.dumps(str(a))
with open('history_finetuning_1241_70_to_90_epoch_nadam_0dot0001_msle_exp_mse.json', 'w') as fp:
    json.dump(str(history.history), fp)

# %%
#model.save_weights('/home/sergio/Documents/weights_saved/pesos_1241_50_to_70_epoch_nadam_0dot0001_msle_exp_mse')

# %% [markdown]
# ## Batch 16, con pesos 1,4,4,1 with lr=1e-5 y usando msle para el (x,y) y usando mse de las exponenciales para (w,h) SIGUIENTES 20 EPOCAS.

# %%
anchors =tf.constant(np.array([[0.026,0.062],[0.067,0.183],[0.128,0.323],[0.343,0.650]]),dtype=tf.float32)
model = TinyYOLOv3(1,anchor_boxes=anchors,train=True,mode = "finetuning")
model.build(batch_input_shape=(None,416,416,3))
print(model.load_weights_darknet("/home/sergio/TinyYOLOv3-Pedestrian-Detection/yolov3-tiny.weights"))
model.load_weights('/home/sergio/Documents/weights_saved/pesos_1241_70_to_90_epoch_nadam_0dot0001_msle_exp_mse')
# Out:
# Pesos de la convolucion (432,)
# CONV SHAPE (16, 3, 3, 3)
# Pesos de la convolucion (4608,)
# CONV SHAPE (32, 16, 3, 3)
# Pesos de la convolucion (18432,)
# CONV SHAPE (64, 32, 3, 3)
# Pesos de la convolucion (73728,)
# CONV SHAPE (128, 64, 3, 3)
# Pesos de la convolucion (294912,)
# CONV SHAPE (256, 128, 3, 3)
# Pesos de la convolucion (1179648,)
# CONV SHAPE (512, 256, 3, 3)
# Pesos de la convolucion (4718592,)
# CONV SHAPE (1024, 512, 3, 3)
# Pesos de la convolucion (262144,)
# CONV SHAPE (256, 1024, 1, 1)
# Pesos de la convolucion (1179648,)
# CONV SHAPE (512, 256, 3, 3)
# Pesos de la convolucion (130560,)
# CONV SHAPE (255, 512, 1, 1)
# Pesos de la convolucion (32768,)
# CONV SHAPE (128, 256, 1, 1)
# Pesos de la convolucion (884736,)
# CONV SHAPE (256, 384, 3, 3)
# Pesos de la convolucion (65280,)
# CONV SHAPE (255, 256, 1, 1)
# 8858734

# %%
for l in model.layers:
    print(l.name, l.trainable)
    pass
# Out:
# BasicBlock1 True
# BasicBlock2 True
# BasicBlock3 True
# BasicBlock4 True
# BasicBlock5 True
# BasicBlock6 True
# BasicBlock7 True
# BasicBlock8 True
# BasicBlock9 True
# FinalBlock1 True
# BasicBlock11 True
# BasicBlock12 True
# FinalBlock2 True
# Concatenate True
# Upsampling True
# Prediction1 True
# Prediction2 True
# Concatenate_BBOX True

# %%
tf.random.set_seed(0)

from tensorflow.keras.metrics import TrueNegatives,TruePositives,FalseNegatives,FalsePositives,Precision,Recall

opt = tf.keras.optimizers.Nadam(learning_rate=1e-5)

losses = {"output_1": loss_xy,
          "output_2": loss_wh,
          "output_3":loss_objectness,
          "output_4":loss_no_objectness  
}

metrics = {"output_3":[Precision(),Recall(),TrueNegatives(),TruePositives(),FalseNegatives(),FalsePositives()]}
model.compile(optimizer=opt, loss=losses,metrics=metrics,loss_weights=[1,4,4,1])
os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")

# %%
history = model.fit(train_dataset, epochs=20,validation_data=val_dataset)
# Out:
# Epoch 1/20
# 4607/4607 [==============================] - 546s 118ms/step - loss: 5.9270 - output_1_loss: 3.4359e-06 - output_2_loss: 0.2993 - output_3_loss: 0.0215 - output_4_loss: 4.6438 - output_3_precision: 0.9042 - output_3_recall: 0.6917 - output_3_true_negatives: 124260744.0000 - output_3_true_positives: 186129.0000 - output_3_false_negatives: 82960.0000 - output_3_false_positives: 19717.0000 - val_loss: 1.6422 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1823 - val_output_3_loss: 0.0045 - val_output_4_loss: 0.8951 - val_output_3_precision: 0.9873 - val_output_3_recall: 0.9716 - val_output_3_true_negatives: 5058073.0000 - val_output_3_true_positives: 11445.0000 - val_output_3_false_negatives: 335.0000 - val_output_3_false_positives: 147.0000
# Epoch 2/20
# 4607/4607 [==============================] - 541s 117ms/step - loss: 5.8870 - output_1_loss: 5.2925e-08 - output_2_loss: 0.2962 - output_3_loss: 0.0212 - output_4_loss: 4.6173 - output_3_precision: 0.9051 - output_3_recall: 0.6948 - output_3_true_negatives: 124260824.0000 - output_3_true_positives: 187045.0000 - output_3_false_negatives: 82163.0000 - output_3_false_positives: 19617.0000 - val_loss: 1.6196 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1807 - val_output_3_loss: 0.0044 - val_output_4_loss: 0.8792 - val_output_3_precision: 0.9870 - val_output_3_recall: 0.9739 - val_output_3_true_negatives: 5058069.0000 - val_output_3_true_positives: 11472.0000 - val_output_3_false_negatives: 308.0000 - val_output_3_false_positives: 151.0000
# Epoch 3/20
# 4607/4607 [==============================] - 541s 118ms/step - loss: 5.8749 - output_1_loss: 1.1398e-09 - output_2_loss: 0.2950 - output_3_loss: 0.0214 - output_4_loss: 4.6093 - output_3_precision: 0.9045 - output_3_recall: 0.6937 - output_3_true_negatives: 124260720.0000 - output_3_true_positives: 186619.0000 - output_3_false_negatives: 82412.0000 - output_3_false_positives: 19693.0000 - val_loss: 1.6098 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1794 - val_output_3_loss: 0.0044 - val_output_4_loss: 0.8745 - val_output_3_precision: 0.9876 - val_output_3_recall: 0.9716 - val_output_3_true_negatives: 5058076.0000 - val_output_3_true_positives: 11446.0000 - val_output_3_false_negatives: 334.0000 - val_output_3_false_positives: 144.0000
# Epoch 4/20
# 4607/4607 [==============================] - 541s 117ms/step - loss: 5.8822 - output_1_loss: 5.6818e-07 - output_2_loss: 0.2954 - output_3_loss: 0.0213 - output_4_loss: 4.6152 - output_3_precision: 0.9038 - output_3_recall: 0.6928 - output_3_true_negatives: 124260624.0000 - output_3_true_positives: 186422.0000 - output_3_false_negatives: 82675.0000 - output_3_false_positives: 19834.0000 - val_loss: 1.5863 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1792 - val_output_3_loss: 0.0043 - val_output_4_loss: 0.8522 - val_output_3_precision: 0.9886 - val_output_3_recall: 0.9716 - val_output_3_true_negatives: 5058088.0000 - val_output_3_true_positives: 11445.0000 - val_output_3_false_negatives: 335.0000 - val_output_3_false_positives: 132.0000
# Epoch 5/20
# 4607/4607 [==============================] - 533s 116ms/step - loss: 5.8377 - output_1_loss: 2.4043e-07 - output_2_loss: 0.2904 - output_3_loss: 0.0212 - output_4_loss: 4.5913 - output_3_precision: 0.9055 - output_3_recall: 0.6957 - output_3_true_negatives: 124260880.0000 - output_3_true_positives: 187298.0000 - output_3_false_negatives: 81925.0000 - output_3_false_positives: 19548.0000 - val_loss: 1.5977 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1784 - val_output_3_loss: 0.0044 - val_output_4_loss: 0.8666 - val_output_3_precision: 0.9874 - val_output_3_recall: 0.9741 - val_output_3_true_negatives: 5058074.0000 - val_output_3_true_positives: 11475.0000 - val_output_3_false_negatives: 305.0000 - val_output_3_false_positives: 146.0000
# Epoch 6/20
# 4607/4607 [==============================] - 550s 119ms/step - loss: 5.7452 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2843 - output_3_loss: 0.0208 - output_4_loss: 4.5246 - output_3_precision: 0.9073 - output_3_recall: 0.7005 - output_3_true_negatives: 124261360.0000 - output_3_true_positives: 188463.0000 - output_3_false_negatives: 80591.0000 - output_3_false_positives: 19261.0000 - val_loss: 1.5832 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1789 - val_output_3_loss: 0.0043 - val_output_4_loss: 0.8503 - val_output_3_precision: 0.9878 - val_output_3_recall: 0.9729 - val_output_3_true_negatives: 5058079.0000 - val_output_3_true_positives: 11461.0000 - val_output_3_false_negatives: 319.0000 - val_output_3_false_positives: 141.0000
# Epoch 7/20
# 4607/4607 [==============================] - 539s 117ms/step - loss: 5.8303 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2896 - output_3_loss: 0.0212 - output_4_loss: 4.5873 - output_3_precision: 0.9054 - output_3_recall: 0.6961 - output_3_true_negatives: 124260776.0000 - output_3_true_positives: 187350.0000 - output_3_false_negatives: 81801.0000 - output_3_false_positives: 19577.0000 - val_loss: 1.5779 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1774 - val_output_3_loss: 0.0043 - val_output_4_loss: 0.8512 - val_output_3_precision: 0.9888 - val_output_3_recall: 0.9741 - val_output_3_true_negatives: 5058090.0000 - val_output_3_true_positives: 11475.0000 - val_output_3_false_negatives: 305.0000 - val_output_3_false_positives: 130.0000
# Epoch 8/20
# 4607/4607 [==============================] - 530s 115ms/step - loss: 5.8479 - output_1_loss: 2.3267e-07 - output_2_loss: 0.2917 - output_3_loss: 0.0214 - output_4_loss: 4.5958 - output_3_precision: 0.9058 - output_3_recall: 0.6957 - output_3_true_negatives: 124260944.0000 - output_3_true_positives: 187250.0000 - output_3_false_negatives: 81902.0000 - output_3_false_positives: 19474.0000 - val_loss: 1.5658 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1772 - val_output_3_loss: 0.0043 - val_output_4_loss: 0.8398 - val_output_3_precision: 0.9876 - val_output_3_recall: 0.9738 - val_output_3_true_negatives: 5058076.0000 - val_output_3_true_positives: 11471.0000 - val_output_3_false_negatives: 309.0000 - val_output_3_false_positives: 144.0000
# Epoch 9/20
# 4607/4607 [==============================] - 543s 118ms/step - loss: 5.8000 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2881 - output_3_loss: 0.0210 - output_4_loss: 4.5638 - output_3_precision: 0.9070 - output_3_recall: 0.6977 - output_3_true_negatives: 124261304.0000 - output_3_true_positives: 187782.0000 - output_3_false_negatives: 81373.0000 - output_3_false_positives: 19248.0000 - val_loss: 1.5517 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1748 - val_output_3_loss: 0.0042 - val_output_4_loss: 0.8356 - val_output_3_precision: 0.9893 - val_output_3_recall: 0.9738 - val_output_3_true_negatives: 5058096.0000 - val_output_3_true_positives: 11471.0000 - val_output_3_false_negatives: 309.0000 - val_output_3_false_positives: 124.0000
# Epoch 10/20
# 4607/4607 [==============================] - 533s 116ms/step - loss: 5.7668 - output_1_loss: 3.1894e-07 - output_2_loss: 0.2822 - output_3_loss: 0.0210 - output_4_loss: 4.5538 - output_3_precision: 0.9048 - output_3_recall: 0.6976 - output_3_true_negatives: 124260576.0000 - output_3_true_positives: 187833.0000 - output_3_false_negatives: 81404.0000 - output_3_false_positives: 19760.0000 - val_loss: 1.5467 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1744 - val_output_3_loss: 0.0042 - val_output_4_loss: 0.8322 - val_output_3_precision: 0.9900 - val_output_3_recall: 0.9728 - val_output_3_true_negatives: 5058104.0000 - val_output_3_true_positives: 11459.0000 - val_output_3_false_negatives: 321.0000 - val_output_3_false_positives: 116.0000
# Epoch 11/20
# 4607/4607 [==============================] - 552s 120ms/step - loss: 5.7736 - output_1_loss: 6.3363e-08 - output_2_loss: 0.2845 - output_3_loss: 0.0212 - output_4_loss: 4.5508 - output_3_precision: 0.9065 - output_3_recall: 0.6979 - output_3_true_negatives: 124261200.0000 - output_3_true_positives: 187800.0000 - output_3_false_negatives: 81290.0000 - output_3_false_positives: 19363.0000 - val_loss: 1.5661 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1726 - val_output_3_loss: 0.0043 - val_output_4_loss: 0.8583 - val_output_3_precision: 0.9870 - val_output_3_recall: 0.9761 - val_output_3_true_negatives: 5058069.0000 - val_output_3_true_positives: 11498.0000 - val_output_3_false_negatives: 282.0000 - val_output_3_false_positives: 151.0000
# Epoch 12/20
# 4607/4607 [==============================] - 543s 118ms/step - loss: 5.8266 - output_1_loss: 9.8422e-07 - output_2_loss: 0.2859 - output_3_loss: 0.0213 - output_4_loss: 4.5979 - output_3_precision: 0.9055 - output_3_recall: 0.6936 - output_3_true_negatives: 124261088.0000 - output_3_true_positives: 186714.0000 - output_3_false_negatives: 82475.0000 - output_3_false_positives: 19482.0000 - val_loss: 1.5349 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1730 - val_output_3_loss: 0.0042 - val_output_4_loss: 0.8264 - val_output_3_precision: 0.9874 - val_output_3_recall: 0.9761 - val_output_3_true_negatives: 5058073.0000 - val_output_3_true_positives: 11498.0000 - val_output_3_false_negatives: 282.0000 - val_output_3_false_positives: 147.0000
# Epoch 13/20
# 4607/4607 [==============================] - 553s 120ms/step - loss: 5.7725 - output_1_loss: 2.3393e-07 - output_2_loss: 0.2833 - output_3_loss: 0.0210 - output_4_loss: 4.5553 - output_3_precision: 0.9058 - output_3_recall: 0.6975 - output_3_true_negatives: 124261016.0000 - output_3_true_positives: 187719.0000 - output_3_false_negatives: 81408.0000 - output_3_false_positives: 19527.0000 - val_loss: 1.5212 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1728 - val_output_3_loss: 0.0041 - val_output_4_loss: 0.8136 - val_output_3_precision: 0.9893 - val_output_3_recall: 0.9767 - val_output_3_true_negatives: 5058095.0000 - val_output_3_true_positives: 11505.0000 - val_output_3_false_negatives: 275.0000 - val_output_3_false_positives: 125.0000
# Epoch 14/20
# 4607/4607 [==============================] - 550s 119ms/step - loss: 5.7265 - output_1_loss: 3.0408e-06 - output_2_loss: 0.2806 - output_3_loss: 0.0208 - output_4_loss: 4.5207 - output_3_precision: 0.9066 - output_3_recall: 0.7000 - output_3_true_negatives: 124261064.0000 - output_3_true_positives: 188349.0000 - output_3_false_negatives: 80703.0000 - output_3_false_positives: 19394.0000 - val_loss: 1.5067 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1713 - val_output_3_loss: 0.0041 - val_output_4_loss: 0.8052 - val_output_3_precision: 0.9892 - val_output_3_recall: 0.9756 - val_output_3_true_negatives: 5058094.0000 - val_output_3_true_positives: 11493.0000 - val_output_3_false_negatives: 287.0000 - val_output_3_false_positives: 126.0000
# Epoch 15/20
# 4607/4607 [==============================] - 545s 118ms/step - loss: 5.7751 - output_1_loss: 6.5694e-07 - output_2_loss: 0.2868 - output_3_loss: 0.0209 - output_4_loss: 4.5441 - output_3_precision: 0.9063 - output_3_recall: 0.6977 - output_3_true_negatives: 124260696.0000 - output_3_true_positives: 187804.0000 - output_3_false_negatives: 81360.0000 - output_3_false_positives: 19423.0000 - val_loss: 1.4843 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1708 - val_output_3_loss: 0.0040 - val_output_4_loss: 0.7854 - val_output_3_precision: 0.9898 - val_output_3_recall: 0.9755 - val_output_3_true_negatives: 5058102.0000 - val_output_3_true_positives: 11491.0000 - val_output_3_false_negatives: 289.0000 - val_output_3_false_positives: 118.0000
# Epoch 16/20
# 4607/4607 [==============================] - 553s 120ms/step - loss: 5.7581 - output_1_loss: 4.4364e-07 - output_2_loss: 0.2855 - output_3_loss: 0.0208 - output_4_loss: 4.5328 - output_3_precision: 0.9052 - output_3_recall: 0.6986 - output_3_true_negatives: 124260912.0000 - output_3_true_positives: 188038.0000 - output_3_false_negatives: 81130.0000 - output_3_false_positives: 19689.0000 - val_loss: 1.5211 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1705 - val_output_3_loss: 0.0041 - val_output_4_loss: 0.8227 - val_output_3_precision: 0.9890 - val_output_3_recall: 0.9780 - val_output_3_true_negatives: 5058092.0000 - val_output_3_true_positives: 11521.0000 - val_output_3_false_negatives: 259.0000 - val_output_3_false_positives: 128.0000
# Epoch 17/20
# 4607/4607 [==============================] - 546s 118ms/step - loss: 5.7256 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2803 - output_3_loss: 0.0208 - output_4_loss: 4.5213 - output_3_precision: 0.9069 - output_3_recall: 0.6993 - output_3_true_negatives: 124261272.0000 - output_3_true_positives: 188183.0000 - output_3_false_negatives: 80905.0000 - output_3_false_positives: 19325.0000 - val_loss: 1.4970 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1695 - val_output_3_loss: 0.0040 - val_output_4_loss: 0.8028 - val_output_3_precision: 0.9905 - val_output_3_recall: 0.9752 - val_output_3_true_negatives: 5058110.0000 - val_output_3_true_positives: 11488.0000 - val_output_3_false_negatives: 292.0000 - val_output_3_false_positives: 110.0000
# Epoch 18/20
# 4607/4607 [==============================] - 547s 119ms/step - loss: 5.7513 - output_1_loss: 7.6071e-08 - output_2_loss: 0.2827 - output_3_loss: 0.0210 - output_4_loss: 4.5364 - output_3_precision: 0.9053 - output_3_recall: 0.6989 - output_3_true_negatives: 124260728.0000 - output_3_true_positives: 188077.0000 - output_3_false_negatives: 81022.0000 - output_3_false_positives: 19669.0000 - val_loss: 1.4898 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1689 - val_output_3_loss: 0.0040 - val_output_4_loss: 0.7983 - val_output_3_precision: 0.9892 - val_output_3_recall: 0.9765 - val_output_3_true_negatives: 5058094.0000 - val_output_3_true_positives: 11503.0000 - val_output_3_false_negatives: 277.0000 - val_output_3_false_positives: 126.0000
# Epoch 19/20
# 4607/4607 [==============================] - 552s 120ms/step - loss: 5.7312 - output_1_loss: 4.5302e-07 - output_2_loss: 0.2784 - output_3_loss: 0.0210 - output_4_loss: 4.5337 - output_3_precision: 0.9059 - output_3_recall: 0.6980 - output_3_true_negatives: 124260832.0000 - output_3_true_positives: 187808.0000 - output_3_false_negatives: 81276.0000 - output_3_false_positives: 19505.0000 - val_loss: 1.4930 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1680 - val_output_3_loss: 0.0040 - val_output_4_loss: 0.8050 - val_output_3_precision: 0.9916 - val_output_3_recall: 0.9763 - val_output_3_true_negatives: 5058123.0000 - val_output_3_true_positives: 11501.0000 - val_output_3_false_negatives: 279.0000 - val_output_3_false_positives: 97.0000
# Epoch 20/20
# 4607/4607 [==============================] - 553s 120ms/step - loss: 5.6941 - output_1_loss: 2.1036e-07 - output_2_loss: 0.2788 - output_3_loss: 0.0207 - output_4_loss: 4.4959 - output_3_precision: 0.9076 - output_3_recall: 0.7019 - output_3_true_negatives: 124261272.0000 - output_3_true_positives: 188862.0000 - output_3_false_negatives: 80222.0000 - output_3_false_positives: 19218.0000 - val_loss: 1.4893 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1666 - val_output_3_loss: 0.0041 - val_output_4_loss: 0.8067 - val_output_3_precision: 0.9897 - val_output_3_recall: 0.9797 - val_output_3_true_negatives: 5058100.0000 - val_output_3_true_positives: 11541.0000 - val_output_3_false_negatives: 239.0000 - val_output_3_false_positives: 120.0000

# %%
os.chdir("/home/sergio/Documents/json_experiments")
import json
#json.dumps(str(a))
with open('history_finetuning_1241_90_to_110_epoch_nadam_0dot0001_msle_exp_mse.json', 'w') as fp:
    json.dump(str(history.history), fp)

# %%
model.save_weights('/home/sergio/Documents/weights_saved/pesos_1241_90_to_110_epoch_nadam_0dot0001_msle_exp_mse')

# %%
os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")
history = model.fit(train_dataset, epochs=20,validation_data=val_dataset)
# Out:
# Epoch 1/20
# 4607/4607 [==============================] - 545s 118ms/step - loss: 5.6469 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2719 - output_3_loss: 0.0205 - output_4_loss: 4.4773 - output_3_precision: 0.9069 - output_3_recall: 0.7028 - output_3_true_negatives: 124260944.0000 - output_3_true_positives: 189148.0000 - output_3_false_negatives: 79984.0000 - output_3_false_positives: 19428.0000 - val_loss: 1.4637 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1672 - val_output_3_loss: 0.0039 - val_output_4_loss: 0.7790 - val_output_3_precision: 0.9902 - val_output_3_recall: 0.9775 - val_output_3_true_negatives: 5058106.0000 - val_output_3_true_positives: 11515.0000 - val_output_3_false_negatives: 265.0000 - val_output_3_false_positives: 114.0000
# Epoch 2/20
# 4607/4607 [==============================] - 529s 115ms/step - loss: 5.7249 - output_1_loss: 9.2667e-07 - output_2_loss: 0.2797 - output_3_loss: 0.0209 - output_4_loss: 4.5223 - output_3_precision: 0.9075 - output_3_recall: 0.6995 - output_3_true_negatives: 124261400.0000 - output_3_true_positives: 188207.0000 - output_3_false_negatives: 80838.0000 - output_3_false_positives: 19194.0000 - val_loss: 1.4588 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1662 - val_output_3_loss: 0.0039 - val_output_4_loss: 0.7783 - val_output_3_precision: 0.9905 - val_output_3_recall: 0.9778 - val_output_3_true_negatives: 5058109.0000 - val_output_3_true_positives: 11519.0000 - val_output_3_false_negatives: 261.0000 - val_output_3_false_positives: 111.0000
# Epoch 3/20
# 4607/4607 [==============================] - 531s 115ms/step - loss: 5.7156 - output_1_loss: 9.7570e-08 - output_2_loss: 0.2808 - output_3_loss: 0.0209 - output_4_loss: 4.5089 - output_3_precision: 0.9062 - output_3_recall: 0.6995 - output_3_true_negatives: 124260912.0000 - output_3_true_positives: 188249.0000 - output_3_false_negatives: 80861.0000 - output_3_false_positives: 19495.0000 - val_loss: 1.4447 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1655 - val_output_3_loss: 0.0039 - val_output_4_loss: 0.7673 - val_output_3_precision: 0.9907 - val_output_3_recall: 0.9769 - val_output_3_true_negatives: 5058112.0000 - val_output_3_true_positives: 11508.0000 - val_output_3_false_negatives: 272.0000 - val_output_3_false_positives: 108.0000
# Epoch 4/20
# 4607/4607 [==============================] - 538s 117ms/step - loss: 5.6880 - output_1_loss: 3.5613e-07 - output_2_loss: 0.2768 - output_3_loss: 0.0208 - output_4_loss: 4.4975 - output_3_precision: 0.9072 - output_3_recall: 0.7005 - output_3_true_negatives: 124261200.0000 - output_3_true_positives: 188549.0000 - output_3_false_negatives: 80600.0000 - output_3_false_positives: 19276.0000 - val_loss: 1.4550 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1638 - val_output_3_loss: 0.0040 - val_output_4_loss: 0.7839 - val_output_3_precision: 0.9897 - val_output_3_recall: 0.9782 - val_output_3_true_negatives: 5058100.0000 - val_output_3_true_positives: 11523.0000 - val_output_3_false_negatives: 257.0000 - val_output_3_false_positives: 120.0000
# Epoch 5/20
# 4607/4607 [==============================] - 552s 120ms/step - loss: 5.6774 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2836 - output_3_loss: 0.0206 - output_4_loss: 4.4606 - output_3_precision: 0.9078 - output_3_recall: 0.7040 - output_3_true_negatives: 124261280.0000 - output_3_true_positives: 189421.0000 - output_3_false_negatives: 79658.0000 - output_3_false_positives: 19234.0000 - val_loss: 1.4486 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1645 - val_output_3_loss: 0.0039 - val_output_4_loss: 0.7751 - val_output_3_precision: 0.9907 - val_output_3_recall: 0.9768 - val_output_3_true_negatives: 5058112.0000 - val_output_3_true_positives: 11507.0000 - val_output_3_false_negatives: 273.0000 - val_output_3_false_positives: 108.0000
# Epoch 6/20
# 4607/4607 [==============================] - 536s 116ms/step - loss: 5.6550 - output_1_loss: 2.8450e-07 - output_2_loss: 0.2735 - output_3_loss: 0.0207 - output_4_loss: 4.4782 - output_3_precision: 0.9083 - output_3_recall: 0.7026 - output_3_true_negatives: 124261384.0000 - output_3_true_positives: 189089.0000 - output_3_false_negatives: 80020.0000 - output_3_false_positives: 19099.0000 - val_loss: 1.4648 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1649 - val_output_3_loss: 0.0040 - val_output_4_loss: 0.7894 - val_output_3_precision: 0.9909 - val_output_3_recall: 0.9754 - val_output_3_true_negatives: 5058115.0000 - val_output_3_true_positives: 11490.0000 - val_output_3_false_negatives: 290.0000 - val_output_3_false_positives: 105.0000
# Epoch 7/20
# 4607/4607 [==============================] - 535s 116ms/step - loss: 5.7592 - output_1_loss: 6.2783e-07 - output_2_loss: 0.2789 - output_3_loss: 0.0211 - output_4_loss: 4.5588 - output_3_precision: 0.9059 - output_3_recall: 0.6969 - output_3_true_negatives: 124261016.0000 - output_3_true_positives: 187543.0000 - output_3_false_negatives: 81570.0000 - output_3_false_positives: 19479.0000 - val_loss: 1.4590 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1633 - val_output_3_loss: 0.0040 - val_output_4_loss: 0.7900 - val_output_3_precision: 0.9891 - val_output_3_recall: 0.9789 - val_output_3_true_negatives: 5058093.0000 - val_output_3_true_positives: 11532.0000 - val_output_3_false_negatives: 248.0000 - val_output_3_false_positives: 127.0000
# Epoch 8/20
# 4607/4607 [==============================] - 539s 117ms/step - loss: 5.6602 - output_1_loss: 6.0197e-07 - output_2_loss: 0.2730 - output_3_loss: 0.0208 - output_4_loss: 4.4851 - output_3_precision: 0.9072 - output_3_recall: 0.7013 - output_3_true_negatives: 124261144.0000 - output_3_true_positives: 188741.0000 - output_3_false_negatives: 80407.0000 - output_3_false_positives: 19308.0000 - val_loss: 1.4449 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1634 - val_output_3_loss: 0.0039 - val_output_4_loss: 0.7759 - val_output_3_precision: 0.9890 - val_output_3_recall: 0.9795 - val_output_3_true_negatives: 5058092.0000 - val_output_3_true_positives: 11539.0000 - val_output_3_false_negatives: 241.0000 - val_output_3_false_positives: 128.0000
# Epoch 9/20
# 4607/4607 [==============================] - 540s 117ms/step - loss: 5.5598 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2710 - output_3_loss: 0.0201 - output_4_loss: 4.3954 - output_3_precision: 0.9086 - output_3_recall: 0.7077 - output_3_true_negatives: 124261160.0000 - output_3_true_positives: 190467.0000 - output_3_false_negatives: 78655.0000 - output_3_false_positives: 19154.0000 - val_loss: 1.4077 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1625 - val_output_3_loss: 0.0037 - val_output_4_loss: 0.7430 - val_output_3_precision: 0.9909 - val_output_3_recall: 0.9781 - val_output_3_true_negatives: 5058114.0000 - val_output_3_true_positives: 11522.0000 - val_output_3_false_negatives: 258.0000 - val_output_3_false_positives: 106.0000
# Epoch 10/20
# 4607/4607 [==============================] - 554s 120ms/step - loss: 5.6140 - output_1_loss: 3.8341e-06 - output_2_loss: 0.2715 - output_3_loss: 0.0206 - output_4_loss: 4.4455 - output_3_precision: 0.9068 - output_3_recall: 0.7035 - output_3_true_negatives: 124261312.0000 - output_3_true_positives: 189355.0000 - output_3_false_negatives: 79788.0000 - output_3_false_positives: 19456.0000 - val_loss: 1.4302 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1621 - val_output_3_loss: 0.0038 - val_output_4_loss: 0.7667 - val_output_3_precision: 0.9898 - val_output_3_recall: 0.9789 - val_output_3_true_negatives: 5058101.0000 - val_output_3_true_positives: 11532.0000 - val_output_3_false_negatives: 248.0000 - val_output_3_false_positives: 119.0000
# Epoch 11/20
# 4607/4607 [==============================] - 552s 120ms/step - loss: 5.6379 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2719 - output_3_loss: 0.0205 - output_4_loss: 4.4680 - output_3_precision: 0.9073 - output_3_recall: 0.7020 - output_3_true_negatives: 124261032.0000 - output_3_true_positives: 188946.0000 - output_3_false_negatives: 80209.0000 - output_3_false_positives: 19297.0000 - val_loss: 1.4251 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1609 - val_output_3_loss: 0.0038 - val_output_4_loss: 0.7662 - val_output_3_precision: 0.9900 - val_output_3_recall: 0.9800 - val_output_3_true_negatives: 5058103.0000 - val_output_3_true_positives: 11544.0000 - val_output_3_false_negatives: 236.0000 - val_output_3_false_positives: 117.0000
# Epoch 12/20
# 4607/4607 [==============================] - 552s 120ms/step - loss: 5.6551 - output_1_loss: 5.1622e-06 - output_2_loss: 0.2782 - output_3_loss: 0.0206 - output_4_loss: 4.4598 - output_3_precision: 0.9071 - output_3_recall: 0.7029 - output_3_true_negatives: 124261184.0000 - output_3_true_positives: 189141.0000 - output_3_false_negatives: 79930.0000 - output_3_false_positives: 19369.0000 - val_loss: 1.4203 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1614 - val_output_3_loss: 0.0038 - val_output_4_loss: 0.7595 - val_output_3_precision: 0.9921 - val_output_3_recall: 0.9779 - val_output_3_true_negatives: 5058128.0000 - val_output_3_true_positives: 11520.0000 - val_output_3_false_negatives: 260.0000 - val_output_3_false_positives: 92.0000
# Epoch 13/20
# 4607/4607 [==============================] - 545s 118ms/step - loss: 5.6203 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2724 - output_3_loss: 0.0204 - output_4_loss: 4.4490 - output_3_precision: 0.9082 - output_3_recall: 0.7038 - output_3_true_negatives: 124261368.0000 - output_3_true_positives: 189445.0000 - output_3_false_negatives: 79723.0000 - output_3_false_positives: 19143.0000 - val_loss: 1.4363 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1596 - val_output_3_loss: 0.0039 - val_output_4_loss: 0.7821 - val_output_3_precision: 0.9917 - val_output_3_recall: 0.9772 - val_output_3_true_negatives: 5058124.0000 - val_output_3_true_positives: 11511.0000 - val_output_3_false_negatives: 269.0000 - val_output_3_false_positives: 96.0000
# Epoch 14/20
# 4607/4607 [==============================] - 541s 117ms/step - loss: 5.6471 - output_1_loss: 9.7929e-08 - output_2_loss: 0.2709 - output_3_loss: 0.0208 - output_4_loss: 4.4804 - output_3_precision: 0.9079 - output_3_recall: 0.7006 - output_3_true_negatives: 124261304.0000 - output_3_true_positives: 188529.0000 - output_3_false_negatives: 80572.0000 - output_3_false_positives: 19136.0000 - val_loss: 1.4144 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1609 - val_output_3_loss: 0.0038 - val_output_4_loss: 0.7558 - val_output_3_precision: 0.9917 - val_output_3_recall: 0.9782 - val_output_3_true_negatives: 5058124.0000 - val_output_3_true_positives: 11523.0000 - val_output_3_false_negatives: 257.0000 - val_output_3_false_positives: 96.0000
# Epoch 15/20
# 4607/4607 [==============================] - 552s 120ms/step - loss: 5.6898 - output_1_loss: 4.3192e-10 - output_2_loss: 0.2801 - output_3_loss: 0.0207 - output_4_loss: 4.4865 - output_3_precision: 0.9070 - output_3_recall: 0.7014 - output_3_true_negatives: 124261296.0000 - output_3_true_positives: 188729.0000 - output_3_false_negatives: 80350.0000 - output_3_false_positives: 19351.0000 - val_loss: 1.4170 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1601 - val_output_3_loss: 0.0038 - val_output_4_loss: 0.7613 - val_output_3_precision: 0.9915 - val_output_3_recall: 0.9789 - val_output_3_true_negatives: 5058121.0000 - val_output_3_true_positives: 11532.0000 - val_output_3_false_negatives: 248.0000 - val_output_3_false_positives: 99.0000
# Epoch 16/20
# 4607/4607 [==============================] - 554s 120ms/step - loss: 5.6160 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2712 - output_3_loss: 0.0205 - output_4_loss: 4.4489 - output_3_precision: 0.9076 - output_3_recall: 0.7039 - output_3_true_negatives: 124260912.0000 - output_3_true_positives: 189446.0000 - output_3_false_negatives: 79692.0000 - output_3_false_positives: 19290.0000 - val_loss: 1.4052 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1590 - val_output_3_loss: 0.0038 - val_output_4_loss: 0.7542 - val_output_3_precision: 0.9923 - val_output_3_recall: 0.9801 - val_output_3_true_negatives: 5058130.0000 - val_output_3_true_positives: 11545.0000 - val_output_3_false_negatives: 235.0000 - val_output_3_false_positives: 90.0000
# Epoch 17/20
# 4607/4607 [==============================] - 549s 119ms/step - loss: 5.5922 - output_1_loss: 6.0534e-07 - output_2_loss: 0.2722 - output_3_loss: 0.0204 - output_4_loss: 4.4217 - output_3_precision: 0.9084 - output_3_recall: 0.7052 - output_3_true_negatives: 124261248.0000 - output_3_true_positives: 189806.0000 - output_3_false_negatives: 79365.0000 - output_3_false_positives: 19149.0000 - val_loss: 1.3939 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1574 - val_output_3_loss: 0.0037 - val_output_4_loss: 0.7495 - val_output_3_precision: 0.9923 - val_output_3_recall: 0.9801 - val_output_3_true_negatives: 5058130.0000 - val_output_3_true_positives: 11546.0000 - val_output_3_false_negatives: 234.0000 - val_output_3_false_positives: 90.0000
# Epoch 18/20
# 4607/4607 [==============================] - 544s 118ms/step - loss: 5.6110 - output_1_loss: 3.3333e-07 - output_2_loss: 0.2723 - output_3_loss: 0.0206 - output_4_loss: 4.4395 - output_3_precision: 0.9076 - output_3_recall: 0.7040 - output_3_true_negatives: 124261296.0000 - output_3_true_positives: 189499.0000 - output_3_false_negatives: 79669.0000 - output_3_false_positives: 19293.0000 - val_loss: 1.3918 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1573 - val_output_3_loss: 0.0037 - val_output_4_loss: 0.7478 - val_output_3_precision: 0.9915 - val_output_3_recall: 0.9812 - val_output_3_true_negatives: 5058121.0000 - val_output_3_true_positives: 11558.0000 - val_output_3_false_negatives: 222.0000 - val_output_3_false_positives: 99.0000
# Epoch 19/20
# 4607/4607 [==============================] - 551s 120ms/step - loss: 5.6218 - output_1_loss: 1.5875e-08 - output_2_loss: 0.2720 - output_3_loss: 0.0206 - output_4_loss: 4.4513 - output_3_precision: 0.9073 - output_3_recall: 0.7025 - output_3_true_negatives: 124261352.0000 - output_3_true_positives: 189033.0000 - output_3_false_negatives: 80065.0000 - output_3_false_positives: 19307.0000 - val_loss: 1.3924 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1568 - val_output_3_loss: 0.0038 - val_output_4_loss: 0.7501 - val_output_3_precision: 0.9913 - val_output_3_recall: 0.9805 - val_output_3_true_negatives: 5058119.0000 - val_output_3_true_positives: 11550.0000 - val_output_3_false_negatives: 230.0000 - val_output_3_false_positives: 101.0000
# Epoch 20/20
# 4607/4607 [==============================] - 551s 120ms/step - loss: 5.6610 - output_1_loss: 3.0132e-07 - output_2_loss: 0.2731 - output_3_loss: 0.0208 - output_4_loss: 4.4855 - output_3_precision: 0.9067 - output_3_recall: 0.7009 - output_3_true_negatives: 124261008.0000 - output_3_true_positives: 188633.0000 - output_3_false_negatives: 80503.0000 - output_3_false_positives: 19415.0000 - val_loss: 1.3644 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1554 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7282 - val_output_3_precision: 0.9918 - val_output_3_recall: 0.9800 - val_output_3_true_negatives: 5058125.0000 - val_output_3_true_positives: 11544.0000 - val_output_3_false_negatives: 236.0000 - val_output_3_false_positives: 95.0000

# %%
os.chdir("/home/sergio/Documents/json_experiments")
import json
#json.dumps(str(a))
with open('history_finetuning_1441_110_to_130_epoch_nadam_0dot000001_msle_exp_mse.json', 'w') as fp:
    json.dump(str(history.history), fp)

# %%
model.save_weights('/home/sergio/Documents/weights_saved/pesos_1441_110_to_130_epoch_nadam_0dot000001_msle_exp_mse')

# %%
tf.random.set_seed(0)

from tensorflow.keras.metrics import TrueNegatives,TruePositives,FalseNegatives,FalsePositives,Precision,Recall

opt = tf.keras.optimizers.Nadam(learning_rate=1e-6)

losses = {"output_1": loss_xy,
          "output_2": loss_wh,
          "output_3":loss_objectness,
          "output_4":loss_no_objectness  
}

metrics = {"output_3":[Precision(),Recall(),TrueNegatives(),TruePositives(),FalseNegatives(),FalsePositives()]}
model.compile(optimizer=opt, loss=losses,metrics=metrics,loss_weights=[1,4,4,1])
os.chdir("/home/sergio/Documents/pedestrian_dataset_train_tfr")

# %%
history = model.fit(train_dataset, epochs=10,validation_data=val_dataset)
# Out:
# Epoch 1/10
# 4607/4607 [==============================] - 547s 119ms/step - loss: 5.5932 - output_1_loss: 2.0272e-06 - output_2_loss: 0.2727 - output_3_loss: 0.0206 - output_4_loss: 4.4201 - output_3_precision_1: 0.9091 - output_3_recall_1: 0.7044 - output_3_true_negatives_1: 124261560.0000 - output_3_true_positives_1: 189617.0000 - output_3_false_negatives_1: 79575.0000 - output_3_false_positives_1: 18970.0000 - val_loss: 1.3471 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1539 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7172 - val_output_3_precision_1: 0.9929 - val_output_3_recall_1: 0.9803 - val_output_3_true_negatives_1: 5058138.0000 - val_output_3_true_positives_1: 11548.0000 - val_output_3_false_negatives_1: 232.0000 - val_output_3_false_positives_1: 82.0000
# Epoch 2/10
# 4607/4607 [==============================] - 525s 114ms/step - loss: 5.6072 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2659 - output_3_loss: 0.0207 - output_4_loss: 4.4606 - output_3_precision_1: 0.9079 - output_3_recall_1: 0.7024 - output_3_true_negatives_1: 124261264.0000 - output_3_true_positives_1: 189010.0000 - output_3_false_negatives_1: 80084.0000 - output_3_false_positives_1: 19177.0000 - val_loss: 1.3546 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1535 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7262 - val_output_3_precision_1: 0.9936 - val_output_3_recall_1: 0.9808 - val_output_3_true_negatives_1: 5058146.0000 - val_output_3_true_positives_1: 11554.0000 - val_output_3_false_negatives_1: 226.0000 - val_output_3_false_positives_1: 74.0000
# Epoch 3/10
# 4607/4607 [==============================] - 536s 116ms/step - loss: 5.5464 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2626 - output_3_loss: 0.0204 - output_4_loss: 4.4146 - output_3_precision_1: 0.9087 - output_3_recall_1: 0.7049 - output_3_true_negatives_1: 124261592.0000 - output_3_true_positives_1: 189674.0000 - output_3_false_negatives_1: 79392.0000 - output_3_false_positives_1: 19060.0000 - val_loss: 1.3452 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1531 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7184 - val_output_3_precision_1: 0.9927 - val_output_3_recall_1: 0.9820 - val_output_3_true_negatives_1: 5058135.0000 - val_output_3_true_positives_1: 11568.0000 - val_output_3_false_negatives_1: 212.0000 - val_output_3_false_positives_1: 85.0000
# Epoch 4/10
# 4607/4607 [==============================] - 538s 117ms/step - loss: 5.5479 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2682 - output_3_loss: 0.0203 - output_4_loss: 4.3942 - output_3_precision_1: 0.9104 - output_3_recall_1: 0.7068 - output_3_true_negatives_1: 124261656.0000 - output_3_true_positives_1: 190286.0000 - output_3_false_negatives_1: 78934.0000 - output_3_false_positives_1: 18718.0000 - val_loss: 1.3398 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1531 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7134 - val_output_3_precision_1: 0.9928 - val_output_3_recall_1: 0.9820 - val_output_3_true_negatives_1: 5058136.0000 - val_output_3_true_positives_1: 11568.0000 - val_output_3_false_negatives_1: 212.0000 - val_output_3_false_positives_1: 84.0000
# Epoch 5/10
# 4607/4607 [==============================] - 528s 115ms/step - loss: 5.5505 - output_1_loss: 9.6706e-06 - output_2_loss: 0.2703 - output_3_loss: 0.0203 - output_4_loss: 4.3885 - output_3_precision_1: 0.9091 - output_3_recall_1: 0.7064 - output_3_true_negatives_1: 124261368.0000 - output_3_true_positives_1: 190132.0000 - output_3_false_negatives_1: 79020.0000 - output_3_false_positives_1: 19008.0000 - val_loss: 1.3375 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1527 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7123 - val_output_3_precision_1: 0.9925 - val_output_3_recall_1: 0.9824 - val_output_3_true_negatives_1: 5058133.0000 - val_output_3_true_positives_1: 11573.0000 - val_output_3_false_negatives_1: 207.0000 - val_output_3_false_positives_1: 87.0000
# Epoch 6/10
# 4607/4607 [==============================] - 538s 117ms/step - loss: 5.5433 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2667 - output_3_loss: 0.0203 - output_4_loss: 4.3955 - output_3_precision_1: 0.9087 - output_3_recall_1: 0.7053 - output_3_true_negatives_1: 124261376.0000 - output_3_true_positives_1: 189774.0000 - output_3_false_negatives_1: 79295.0000 - output_3_false_positives_1: 19057.0000 - val_loss: 1.3361 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1527 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7110 - val_output_3_precision_1: 0.9932 - val_output_3_recall_1: 0.9824 - val_output_3_true_negatives_1: 5058141.0000 - val_output_3_true_positives_1: 11573.0000 - val_output_3_false_negatives_1: 207.0000 - val_output_3_false_positives_1: 79.0000
# Epoch 7/10
# 4607/4607 [==============================] - 540s 117ms/step - loss: 5.5448 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2639 - output_3_loss: 0.0203 - output_4_loss: 4.4079 - output_3_precision_1: 0.9087 - output_3_recall_1: 0.7060 - output_3_true_negatives_1: 124261168.0000 - output_3_true_positives_1: 190015.0000 - output_3_false_negatives_1: 79118.0000 - output_3_false_positives_1: 19097.0000 - val_loss: 1.3384 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1522 - val_output_3_loss: 0.0036 - val_output_4_loss: 0.7153 - val_output_3_precision_1: 0.9934 - val_output_3_recall_1: 0.9829 - val_output_3_true_negatives_1: 5058143.0000 - val_output_3_true_positives_1: 11579.0000 - val_output_3_false_negatives_1: 201.0000 - val_output_3_false_positives_1: 77.0000
# Epoch 8/10
# 4607/4607 [==============================] - 533s 116ms/step - loss: 5.5696 - output_1_loss: 0.0000e+00 - output_2_loss: 0.2688 - output_3_loss: 0.0204 - output_4_loss: 4.4129 - output_3_precision_1: 0.9089 - output_3_recall_1: 0.7051 - output_3_true_negatives_1: 124261584.0000 - output_3_true_positives_1: 189741.0000 - output_3_false_negatives_1: 79354.0000 - output_3_false_positives_1: 19024.0000 - val_loss: 1.3340 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1524 - val_output_3_loss: 0.0035 - val_output_4_loss: 0.7102 - val_output_3_precision_1: 0.9934 - val_output_3_recall_1: 0.9833 - val_output_3_true_negatives_1: 5058143.0000 - val_output_3_true_positives_1: 11583.0000 - val_output_3_false_negatives_1: 197.0000 - val_output_3_false_positives_1: 77.0000
# Epoch 9/10
# 4607/4607 [==============================] - 545s 118ms/step - loss: 5.5856 - output_1_loss: 1.3195e-06 - output_2_loss: 0.2672 - output_3_loss: 0.0205 - output_4_loss: 4.4348 - output_3_precision_1: 0.9077 - output_3_recall_1: 0.7041 - output_3_true_negatives_1: 124261232.0000 - output_3_true_positives_1: 189555.0000 - output_3_false_negatives_1: 79656.0000 - output_3_false_positives_1: 19280.0000 - val_loss: 1.3305 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1525 - val_output_3_loss: 0.0035 - val_output_4_loss: 0.7065 - val_output_3_precision_1: 0.9929 - val_output_3_recall_1: 0.9823 - val_output_3_true_negatives_1: 5058137.0000 - val_output_3_true_positives_1: 11572.0000 - val_output_3_false_negatives_1: 208.0000 - val_output_3_false_positives_1: 83.0000
# Epoch 10/10
# 4607/4607 [==============================] - 546s 119ms/step - loss: 5.5390 - output_1_loss: 1.1279e-05 - output_2_loss: 0.2672 - output_3_loss: 0.0203 - output_4_loss: 4.3891 - output_3_precision_1: 0.9094 - output_3_recall_1: 0.7069 - output_3_true_negatives_1: 124261472.0000 - output_3_true_positives_1: 190333.0000 - output_3_false_negatives_1: 78908.0000 - output_3_false_positives_1: 18971.0000 - val_loss: 1.3225 - val_output_1_loss: 0.0000e+00 - val_output_2_loss: 0.1522 - val_output_3_loss: 0.0035 - val_output_4_loss: 0.6998 - val_output_3_precision_1: 0.9933 - val_output_3_recall_1: 0.9826 - val_output_3_true_negatives_1: 5058142.0000 - val_output_3_true_positives_1: 11575.0000 - val_output_3_false_negatives_1: 205.0000 - val_output_3_false_positives_1: 78.0000

# %%
os.chdir("/home/sergio/Documents/json_experiments")
import json
#json.dumps(str(a))
with open('history_finetuning_1441_130_to_140_epoch_nadam_0dot000001_msle_exp_mse.json', 'w') as fp:
    json.dump(str(history.history), fp)

# %%
model.save_weights('/home/sergio/Documents/weights_saved/pesos_1441_130_to_140_epoch_nadam_0dot000001_msle_exp_mse')
